# %%
###############################################################################
# The Institute for the Design of Advanced Energy Systems Integrated Platform
# Framework (IDAES IP) was produced under the DOE Institute for the
# Design of Advanced Energy Systems (IDAES).
#
# Copyright (c) 2018-2023 by the software owners: The Regents of the
# University of California, through Lawrence Berkeley National Laboratory,
# National Technology & Engineering Solutions of Sandia, LLC, Carnegie Mellon
# University, West Virginia University Research Corporation, et al.
# All rights reserved.  Please see the files COPYRIGHT.md and LICENSE.md
# for full copyright and license information.
###############################################################################

# %% [markdown]
# ![IDAES logo](idaes-logo-small.png)
#
# # Flowsheet Visualizer Tutorial
# > Author: Dan Gunter \
# > Created: 2022-07-05
#
# ## Outline
#
# - Introduction
# - Example flowsheet
# - Running the Flowsheet Visualizer
# - Running from a script
# - Further reading

# %% [markdown]
# ## Introduction
# The IDAES Flowsheet Visualizer (FV) is a Python tool that provides a web-based visualization of any existing IDAES model or flowsheet. The visualization shows a diagram of the
# flowsheet as well as a stream table. You can interact with the diagram and export
# it as an image for inclusion in presentations or publications.
#
# This tutorial will show the basic steps of running the FV on an example
# flowsheet, interacting with the resulting GUI, saving your work, and exporting
# the diagram as an image. It will also show how the Visualizer can be updated
# to reflect changes in the model components and/or variable values. The tutorial
# will also show how to run the Visualizer from a Python script.

# %% [markdown]
# ## Example flowsheet
# This initial section creates an example flowsheet.
#
# ### Setup
# Module imports and any additional housekeeping needed
# to initialize the code.

# %%
import idaes_examples.mod.tut.visualizer_tutorial as vistut

vistut.quiet()  # turn off default logging and most warnings
from idaes.core.util.model_statistics import degrees_of_freedom
from IPython.display import Markdown

# %% [markdown]
# ### Create the flowsheet

# %%
# use the pre-defined function to create the flowsheet
model = vistut.create_model()

# description of the flowsheet we created
display(Markdown(vistut.function_markdown(vistut.create_model)))

vistut.quiet()

# initialize the flowsheet as a square problem (dof=0)
#vistut.initialize_model(model)

# verify that there are zero degrees of freedom
print(f"DOF = {degrees_of_freedom(model)}")

model.fs.visualize("UI demo")
# Out:
# ## Create an IDAES flowsheet for hydrodealkylation (HDA)
# ### About HDA
#
# Hydrodealkylation (HDA) is a chemical reaction that often involves reacting
# an aromatic hydrocarbon in the presence of hydrogen gas to form a
# simpler aromatic hydrocarbon devoid of functional groups. In this
# example, toluene will be reacted with hydrogen gas at high temperatures
# to form benzene via the following reaction:
#
# **C<sub>6</sub>H<sub>5</sub>CH<sub>3</sub> + H<sub>2</sub> → C<sub>6</sub>H<sub>6</sub> + CH<sub>4</sub>**
#
# This reaction is often accompanied by an equilibrium side reaction
# which forms diphenyl, which we will not cover in this example.
#
# ### References
#
# This example is based on the 1967 AIChE Student Contest problem as
# present by Douglas, J.M., Chemical  Design of Chemical Processes, 1988,
# McGraw-Hill.
# DOF = 0
# 2023-09-22 07:34:22 [INFO] idaes.idaes_ui.fv.fsvis: Started visualization server
# 2023-09-22 07:34:22 [INFO] idaes.idaes_ui.fv.fsvis: Loading saved flowsheet from 'UI demo.json'
# 2023-09-22 07:34:22 [INFO] idaes.idaes_ui.fv.fsvis: Saving flowsheet to default file 'UI demo.json' in current directory (C:\Users\dkgun\src\dangunter\examples\idaes_examples\notebooks\docs\tut\ui)
# 2023-09-22 07:34:22 [WARNING] idaes.idaes_ui.fv.flowsheet: Cannot extract state block from Port: name=liq_outlet. Please add Feed & Product blocks with Arcs to show inlet and outlet stream values in the Stream Table
# 2023-09-22 07:34:22 [WARNING] idaes.idaes_ui.fv.flowsheet: Port is neither a feed nor a product: name=purge feed-expr=re.compile('^in_|^feed_|^inlet_|^in$|^feed$|^inlet$|_in$|_feed$|_inlet$', re.IGNORECASE) product-expr=re.compile('^out_|^prod_|^outlet_|^out$|^prod$|^outlet$|_out$|_prod$|_outlet$', re.IGNORECASE)
# 2023-09-22 07:34:22 [WARNING] idaes.idaes_ui.fv.fsvis: Flowsheet name changed: old='UI demo' new='UI-demo'
# Flowsheet name changed to 'UI-demo'
# 2023-09-22 07:34:22 [INFO] idaes.idaes_ui.fv.fsvis: Flowsheet visualization at: http://localhost:50329/app?id=UI-demo

# %% [markdown]
# ## Running the Flowsheet Visualizer
# In most cases, you will run the FV by calling the `visualize()` method attached to your flowsheet.
# This function takes a number of optional arguments, which we will look at briefly later, and one required argument:
# the **title** to give the visualization. Unless you give more information, this title also is used as the filename in which to save its current state.
#
# In the following, we start the FV with the title "Hydrodealkylation". This will pop up a new browser tab (and save the status in a file called _Hydrodealkylation.json_).
#
# <div class="alert alert-block alert-info">
# After the visualizer starts, we recommend making its tab into its own browser window and viewing it side-by-side with this notebook window.
# </div>

# %% [markdown]
# ### Optional arguments
# The optional (keyword) arguments are documented in the base function, which can be found in `idaes.core.ui.fsvis.visualize`:
#
#   * name: Name of flowsheet to display as the title of the visualization
#   * load_from_saved: If True load from saved file if any. Otherwise create
#     a new file or overwrite it (depending on 'overwrite' flag).
#   * save: Where to save the current flowsheet layout and values. If this argument is not specified,
#     "``name``.json" will be used (if this file already exists, a "-`<version>`" number will be added
#     between the name and the extension). If the value given is the boolean 'False', then nothing
#     will be saved. The boolean 'True' value is treated the same as unspecified.
#   * save_dir: If this argument is given, and ``save`` is not given or a relative path, then it will
#     be used as the directory to save the default or given file. The current working directory is
#     the default. If ``save`` is given and an absolute path, this argument is ignored.
#   * save_time_interval: The time interval that the UI application checks if any changes has occurred
#     in the graph for it to save the model. Default is 5 seconds
#   * overwrite: If True, and the file given by ``save`` exists, overwrite instead of creating a new
#     numbered file.
#   * browser: If true, open a browser
#   * port: Start listening on this port. If not given, find an open port.
#   * log_level: An IDAES logging level, which is a superset of the built-in `logging` module levels.
#     See the `idaes.logger` module for details
#   * quiet: If True, suppress printing any messages to standard output (console)
#   * loop_forever: If True, don't return but instead loop until a Control-C is received. Useful when
#     invoking this function at the end of a script.

# %% [markdown]
# ## Interacting with the visualizer
# The first things you need to learn about the FV are how to manipulate the overall layout and control the view.
# The UI should initially look something like the screenshot below:
# ![](fv1.png)
#
# <div class="alert alert-block alert-info">
#     As you can see, the FV has two main panels. We will call the top panel the <b>diagram</b> and the bottom panel the <b>stream table</b>.
# </div>

# %% [markdown]
# ### View controls
# Before looking at the two panels in detail, it helps to know some basic controls for making them easier to view.
#
# | Control | Description | Illustration |
# |:----|:---------------------|:----:|
# | Panel height | Change the height of the  panels by grabbing the small handle in the lower right corner with your mouse. | ![](fv2.png) |
# | Diagram size | Zoom in/out on the diagram with the magnifying glass "+" and "-" buttons in the upper-right corner of the top panel. The button labeled with two crossing arrows fits the diagram into the current panel height and width. | ![](fv3.png) |

# %% [markdown]
# ### Rearranging the diagram
# The diagram shown in the top panel is interactive. You can move the units shown there into different positions. Whatever arrangement you end up with will be saved for next time. The arcs (i.e., lines representing streams) connecting the units will automatically re-route themselves as you move them. Below is a summary of the different actions you can take when rearranging the diagram.
#
# | &nbsp; | &nbsp; |
# |:--:|:--:|
# | ![](fvr1.png) &nbsp; | &nbsp; ![](fvr2.png) |
# | ![](fvr3.png) &nbsp; | &nbsp; ![](fvr4.png) |

# %% [markdown]
# ### Stream table
# The stream table panel shows the values of variables on all the streams between units, and also from units to outlets.
#
# ### Stream table "brushing"
# Brushing refers to the ability to have actions in one visual area influence the display in another. It is commonly used in statistics to show how points in one scatterplot correspond to their points in another, for the same samples. Here, we use it to link the position of a stream in the diagram with its variable values in the stream table.
# #### Controls
#
# * Moving the mouse over an **arc** in the diagram &rarr; highlights the corresponding **column** in the stream table
# * Moving the mouse over a **column** in the stream table &rarr; highlights the corresponding **arc** in the diagram
#
# ![Illustration of stream table brushing](fvb1.png)
#
# #### Example
# Stream table brushing is useful for answering questions like:
# > How much benzene are we losing in the F101 vapor outlet stream?
#
# To answer this question, we will use some interactive elements of the stream table.
#
# 1. Find the inlet of F101 on the diagram. Mouse over this to see the values for that stream highlighted in the stream table below. This is stream `s05`. Look across at the row for Benzene vapor (`flow_mol_phase_comp('Vap', 'benzene')`) and see that the value is $0.35384$
# 2. Find the vapor outlet of F101 by looking for the arc connecting to the splitter and compressor feedback loop. This is stream `s06`. Then look at the same row for the Benzene vapor mol fraction and see that the value is $0.14916$
# 3. Thus the amount of benzene lost is (in mole fractions) about $0.2$

# %% [markdown]
# ### Showing and hiding streams
# For complex diagrams, there are a lot of streams and the stream table does not fit in the window. To avoid having to scroll back and forth, there is the ability to "hide" selected streams in the stream table.
#
# * Click on the "Hide Fields" menu and select which fields to hide
# * The mark will toggle between a check (shown) and open circle (hidden)
#
# For example, we can hide all the streams except the feeds and the flash inlets and outlets.
#
# ![Illustration of stream table field hiding](fvst1.png)

# %% [markdown]
# ### Saving and loading
# The current layout and status can be saved to a file, and this file can then be loaded when the model is viewed again. The main benefit is that interactive layout of the diagram is saved for re-use.
#
# #### File name
# This file is named, by default, for the title of the visualizer (e.g., "Hydrodealkylation") with a ".json" extension to indicate the data format and saved in the same directory as the Jupyter notebook.
#
# You can select a different filename and location when you start the visualization, e.g.
#
#     model.fs.visualize("The Title", save="thefilename.json", save_dir="/path/to/save/the/file")
#
# #### Reloading
# To reload the saved layout, simply choose the same title (since the filename, by default, matches the title) or explicitly use the `save` and `save_dir` keywords for the `visualize()` function to select a previously saved file. This means you only need to manually lay out the diagram once. Of course, if you add new pieces to the flowsheet you will need to position them correctly (as discussed below).

# %% [markdown]
# ### Exporting
#
# #### Exporting the diagram as an image
# You can export an image of the flowsheet diagram in the [Scalable Vector Graphics (SVG)](https://www.w3.org/Graphics/SVG/) format, which can render without fuzziness at arbitrary sizes. Almost all presentation and drawing programs, including MS Word and Powerpoint, can use SVG images.
#
# From the top menu select _Export -> Flowsheet_. You will get a preview of the flowsheet that you can then download to a file.
# #### Exporting the stream table as CSV
# You can export the stream table as comma-separated values. From the top menu select _Export -> Stream Table_.

# %% [markdown]
# ### Updating when the flowsheet changes
# The FV has a connection to the Python program that has the flowsheet (model) in memory. Therefore, when the underlying flowsheet changes, the visualization can be quickly updated to show the new state. This feature is particularly useful for interactive flowsheet creation and debugging in Jupyter Notebooks.
#
# To illustrate the feature, below is some IDAES modeling code that adds another Flash unit to the model, connecting the liquid outlet of the first flash unit to its inlet. There is a little more code that updates some of the output values of the model and sets initial values for this new unit, and then re-initializes the model.
#
# **After this code executes, the model will have a unit called "F102" connected to "F101".**

# %%
# Add a second flash unit
from idaes.models.unit_models import Flash
from pyomo.network import Arc
from pyomo.environ import Expression, TransformationFactory

m = model  # alias
m.fs.F102 = Flash(
    property_package=m.fs.thermo_params,
    has_heat_transfer=True,
    has_pressure_change=True,
)
# connect to 1st flash unit
m.fs.s10 = Arc(source=m.fs.F101.liq_outlet, destination=m.fs.F102.inlet)
# update expressions for purity and cost
m.fs.purity = Expression(
    expr=m.fs.F102.vap_outlet.flow_mol_phase_comp[0, "Vap", "benzene"]
    / (
        m.fs.F102.vap_outlet.flow_mol_phase_comp[0, "Vap", "benzene"]
        + m.fs.F102.vap_outlet.flow_mol_phase_comp[0, "Vap", "toluene"]
    )
)
m.fs.heating_cost = Expression(
    expr=2.2e-7 * m.fs.H101.heat_duty[0] + 1.9e-7 * m.fs.F102.heat_duty[0]
)
# fix unit output and pressure drop
m.fs.F102.vap_outlet.temperature.fix(375)
m.fs.F102.deltaP.fix(-200000)

# expand arcs
TransformationFactory("network.expand_arcs").apply_to(m)
# re-initialize
_ = vistut.initialize_model(m)
# Out:
# WARNING: Implicitly replacing the Component attribute purity (type=<class
# 'pyomo.core.base.expression.ScalarExpression'>) on block fs with a new
# Component (type=<class 'pyomo.core.base.expression.ScalarExpression'>). This
# is usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute heating_cost
# (type=<class 'pyomo.core.base.expression.ScalarExpression'>) on block fs with
# a new Component (type=<class 'pyomo.core.base.expression.ScalarExpression'>).
# This is usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# 2023-09-22 07:34:23 [INFO] idaes.init.fs.H101.control_volume.properties_in: Initialization Step 1 - Dew and bubble points calculation completed.
# 2023-09-22 07:34:23 [INFO] idaes.init.fs.H101.control_volume.properties_in: Initialization Step 2 - Equilibrium temperature  calculation completed.
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: tol=1e-06
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: max_iter=200
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: ******************************************************************************
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:          For more information visit http://projects.coin-or.org/Ipopt
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This version of Ipopt was compiled from source code available at
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     for large-scale scientific computation.  All technical papers, sales and
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     publicity material resulting from use of the HSL codes within IPOPT must
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     contain the following acknowledgement:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         HSL, a collection of Fortran codes for large-scale scientific
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         computation. See http://www.hsl.rl.ac.uk.
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: ******************************************************************************
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of nonzeros in equality constraint Jacobian...:       18
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of nonzeros in inequality constraint Jacobian.:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of nonzeros in Lagrangian Hessian.............:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total number of variables............................:       10
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                      variables with only lower bounds:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                 variables with lower and upper bounds:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                      variables with only upper bounds:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total number of equality constraints.................:       10
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total number of inequality constraints...............:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         inequality constraints with only lower bounds:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:    inequality constraints with lower and upper bounds:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         inequality constraints with only upper bounds:        0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:    0  0.0000000e+00 7.00e+08 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:    1  0.0000000e+00 1.94e-08 0.00e+00  -1.0 7.00e+05    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of Iterations....: 1
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                                    (scaled)                 (unscaled)
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Constraint violation....:   1.9441358745098113e-09    1.9441358745098111e-08
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Overall NLP error.......:   1.9441358745098113e-09    1.9441358745098111e-08
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of objective function evaluations             = 2
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of objective gradient evaluations             = 2
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of equality constraint evaluations            = 2
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of inequality constraint evaluations          = 0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of equality constraint Jacobian evaluations   = 2
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of inequality constraint Jacobian evaluations = 0
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of Lagrangian Hessian evaluations             = 1
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total CPU secs in NLP function evaluations           =      0.000
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2023-09-22 07:34:24 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: EXIT: Optimal Solution Found.
# 2023-09-22 07:34:25 [WARNING] idaes.idaes_ui.fv.flowsheet: Cannot extract state block from Port: name=liq_outlet. Please add Feed & Product blocks with Arcs to show inlet and outlet stream values in the Stream Table
# 2023-09-22 07:34:25 [WARNING] idaes.idaes_ui.fv.flowsheet: Cannot extract state block from Port: name=vap_outlet. Please add Feed & Product blocks with Arcs to show inlet and outlet stream values in the Stream Table
# 2023-09-22 07:34:25 [WARNING] idaes.idaes_ui.fv.flowsheet: Port is neither a feed nor a product: name=purge feed-expr=re.compile('^in_|^feed_|^inlet_|^in$|^feed$|^inlet$|_in$|_feed$|_inlet$', re.IGNORECASE) product-expr=re.compile('^out_|^prod_|^outlet_|^out$|^prod$|^outlet$|_out$|_prod$|_outlet$', re.IGNORECASE)
# 2023-09-22 07:34:25 [WARNING] idaes.idaes_ui.fv.flowsheet: Cannot extract state block from Port: name=liq_outlet. Please add Feed & Product blocks with Arcs to show inlet and outlet stream values in the Stream Table
# 2023-09-22 07:34:25 [WARNING] idaes.idaes_ui.fv.flowsheet: Cannot extract state block from Port: name=vap_outlet. Please add Feed & Product blocks with Arcs to show inlet and outlet stream values in the Stream Table
# 2023-09-22 07:34:25 [WARNING] idaes.idaes_ui.fv.flowsheet: Port is neither a feed nor a product: name=purge feed-expr=re.compile('^in_|^feed_|^inlet_|^in$|^feed$|^inlet$|_in$|_feed$|_inlet$', re.IGNORECASE) product-expr=re.compile('^out_|^prod_|^outlet_|^out$|^prod$|^outlet$|_out$|_prod$|_outlet$', re.IGNORECASE)
# 2023-09-22 07:34:25 [INFO] idaes.init.fs.H101.control_volume.properties_out: Initialization Step 1 - Dew and bubble points calculation completed.
# 2023-09-22 07:34:25 [INFO] idaes.init.fs.H101.control_volume.properties_out: Initialization Step 2 - Equilibrium temperature  calculation completed.
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: tol=1e-06
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: max_iter=200
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: ******************************************************************************
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:          For more information visit http://projects.coin-or.org/Ipopt
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This version of Ipopt was compiled from source code available at
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     for large-scale scientific computation.  All technical papers, sales and
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     publicity material resulting from use of the HSL codes within IPOPT must
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     contain the following acknowledgement:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         HSL, a collection of Fortran codes for large-scale scientific
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         computation. See http://www.hsl.rl.ac.uk.
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: ******************************************************************************
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of nonzeros in equality constraint Jacobian...:       31
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of nonzeros in inequality constraint Jacobian.:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of nonzeros in Lagrangian Hessian.............:       11
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total number of variables............................:       17
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                      variables with only lower bounds:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                 variables with lower and upper bounds:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                      variables with only upper bounds:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total number of equality constraints.................:       17
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total number of inequality constraints...............:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         inequality constraints with only lower bounds:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    inequality constraints with lower and upper bounds:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         inequality constraints with only upper bounds:        0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    0  0.0000000e+00 7.00e+08 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    1  0.0000000e+00 9.70e+02 0.00e+00  -1.0 7.69e+05    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    2  0.0000000e+00 6.38e+02 0.00e+00  -1.0 4.73e+06    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    3  0.0000000e+00 3.67e+02 0.00e+00  -1.0 2.00e+07    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    4  0.0000000e+00 1.67e+02 0.00e+00  -1.0 5.27e+07    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    5  0.0000000e+00 4.93e+01 0.00e+00  -1.0 7.34e+07    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    6  0.0000000e+00 5.77e+00 0.00e+00  -1.0 4.19e+07    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    7  0.0000000e+00 9.14e-02 0.00e+00  -1.0 6.27e+06    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    8  0.0000000e+00 2.34e-05 0.00e+00  -2.5 1.02e+05    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    9  0.0000000e+00 1.62e-12 0.00e+00  -5.7 2.62e+01    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of Iterations....: 9
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                                    (scaled)                 (unscaled)
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Constraint violation....:   1.6200374375330284e-12    1.6200374375330284e-12
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Overall NLP error.......:   1.6200374375330284e-12    1.6200374375330284e-12
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of objective function evaluations             = 10
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of objective gradient evaluations             = 10
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of equality constraint evaluations            = 10
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of inequality constraint evaluations          = 0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of equality constraint Jacobian evaluations   = 10
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of inequality constraint Jacobian evaluations = 0
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of Lagrangian Hessian evaluations             = 9
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total CPU secs in NLP function evaluations           =      0.000
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: EXIT: Optimal Solution Found.
# 2023-09-22 07:34:25 [INFO] idaes.init.fs.H101.control_volume.properties_out: State Released.
# 2023-09-22 07:34:25 [INFO] idaes.init.fs.H101.control_volume: Initialization Complete
# 2023-09-22 07:34:25 [INFO] idaes.init.fs.H101: Initialization Step 1 Complete.
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101: tol=1e-06
# 2023-09-22 07:34:25 [DEBUG] idaes.solve.fs.H101: max_iter=200
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: ******************************************************************************
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:          For more information visit http://projects.coin-or.org/Ipopt
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: This version of Ipopt was compiled from source code available at
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:     for large-scale scientific computation.  All technical papers, sales and
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:     publicity material resulting from use of the HSL codes within IPOPT must
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101
1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  100r 0.0000000e+00 5.42e+01 2.75e+06  -3.9 2.27e+02    -  1.00e+00 2.18e-01f  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  101r 0.0000000e+00 5.15e+01 5.37e+06  -3.9 1.72e+02    -  1.67e-01 1.58e-01f  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  102r 0.0000000e+00 3.28e+02 1.83e+08  -3.9 1.61e+02    -  4.21e-01 1.79e-01f  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  103r 0.0000000e+00 3.28e+02 1.81e+08  -3.9 5.02e+01    -  2.51e-02 3.70e-04h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  104r 0.0000000e+00 3.26e+02 1.81e+08  -3.9 6.06e+02    -  1.69e-02 4.20e-03h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  105r 0.0000000e+00 3.18e+02 1.73e+08  -3.9 1.61e+03    -  9.71e-02 1.27e-02f  2
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  106r 0.0000000e+00 1.95e+02 1.05e+08  -3.9 1.95e+02    -  6.07e-01 6.53e-02h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  107r 0.0000000e+00 1.94e+02 1.06e+08  -3.9 1.52e+03    -  7.28e-02 1.84e-03h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  108r 0.0000000e+00 2.32e+02 1.41e+08  -3.9 1.13e+02    -  1.00e+00 8.76e-01f  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  109r 0.0000000e+00 8.57e+00 5.25e+06  -3.9 3.18e+01    -  1.00e+00 3.53e-01h  2
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  110r 0.0000000e+00 1.06e+00 6.48e+05  -3.9 1.15e+01    -  9.81e-01 1.00e+00h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  111r 0.0000000e+00 8.06e-01 6.48e+05  -3.9 9.04e+01    -  1.00e+00 1.16e-01f  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  112r 0.0000000e+00 8.94e-02 7.38e+04  -3.9 2.94e+00    -  1.00e+00 1.00e+00f  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  113r 0.0000000e+00 1.04e-02 6.72e+03  -3.9 1.01e+00    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:  114r 0.0000000e+00 2.21e-05 1.30e+01  -3.9 4.77e-02    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of Iterations....: 114
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:                                    (scaled)                 (unscaled)
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Constraint violation....:   2.5693904537327228e-07    2.2066466213388480e-05
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Overall NLP error.......:   2.5693904537327228e-07    2.2066466213388480e-05
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of objective function evaluations             = 132
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of objective gradient evaluations             = 7
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of equality constraint evaluations            = 132
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of inequality constraint evaluations          = 0
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of equality constraint Jacobian evaluations   = 116
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of inequality constraint Jacobian evaluations = 0
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Number of Lagrangian Hessian evaluations             = 114
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Total CPU secs in IPOPT (w/o function evaluations)   =      0.034
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: Total CPU secs in NLP function evaluations           =      0.000
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.H101: EXIT: Optimal Solution Found.
# 2023-09-22 07:34:26 [INFO] idaes.init.fs.H101: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-09-22 07:34:26 [INFO] idaes.init.fs.H101.control_volume.properties_in: State Released.
# 2023-09-22 07:34:26 [INFO] idaes.init.fs.H101: Initialization Complete: optimal - Optimal Solution Found
# 2023-09-22 07:34:26 [INFO] idaes.init.fs.R101.control_volume.properties_in: Initialization Step 1 - Dew and bubble points calculation completed.
# 2023-09-22 07:34:26 [INFO] idaes.init.fs.R101.control_volume.properties_in: Initialization Step 2 - Equilibrium temperature  calculation completed.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: tol=1e-06
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: max_iter=200
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: ******************************************************************************
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:          For more information visit http://projects.coin-or.org/Ipopt
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: This version of Ipopt was compiled from source code available at
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:     for large-scale scientific computation.  All technical papers, sales and
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:     publicity material resulting from use of the HSL codes within IPOPT must
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:     contain the following acknowledgement:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:         HSL, a collection of Fortran codes for large-scale scientific
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:         computation. See http://www.hsl.rl.ac.uk.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: ******************************************************************************
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: Number of nonzeros in equality constraint Jacobian...:       18
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: Number of nonzeros in inequality constraint Jacobian.:        0
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: Number of nonzeros in Lagrangian Hessian.............:        0
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in:
# 2023-09-22 07:34:26 [DEBUG] idaes.solve.fs.R101.control_volume.properties_in: Total number of variables............................:       10
# ...
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: tol=1e-06
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: max_iter=200
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: ******************************************************************************
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:          For more information visit http://projects.coin-or.org/Ipopt
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: This version of Ipopt was compiled from source code available at
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:     for large-scale scientific computation.  All technical papers, sales and
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:     publicity material resulting from use of the HSL codes within IPOPT must
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:     contain the following acknowledgement:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:         HSL, a collection of Fortran codes for large-scale scientific
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:         computation. See http://www.hsl.rl.ac.uk.
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: ******************************************************************************
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of nonzeros in equality constraint Jacobian...:       31
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of nonzeros in inequality constraint Jacobian.:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of nonzeros in Lagrangian Hessian.............:       11
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Total number of variables............................:       17
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:                      variables with only lower bounds:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:                 variables with lower and upper bounds:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:                      variables with only upper bounds:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Total number of equality constraints.................:       17
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Total number of inequality constraints...............:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:         inequality constraints with only lower bounds:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:    inequality constraints with lower and upper bounds:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:         inequality constraints with only upper bounds:        0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:    0  0.0000000e+00 1.88e+04 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:    1  0.0000000e+00 4.55e-13 0.00e+00  -1.0 1.88e+04    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of Iterations....: 1
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:                                    (scaled)                 (unscaled)
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Constraint violation....:   4.5474735088646412e-13    4.5474735088646412e-13
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Overall NLP error.......:   4.5474735088646412e-13    4.5474735088646412e-13
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of objective function evaluations             = 2
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of objective gradient evaluations             = 2
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of equality constraint evaluations            = 2
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of inequality constraint evaluations          = 0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of equality constraint Jacobian evaluations   = 2
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of inequality constraint Jacobian evaluations = 0
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Number of Lagrangian Hessian evaluations             = 1
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: Total CPU secs in NLP function evaluations           =      0.000
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out:
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102.control_volume.properties_out: EXIT: Optimal Solution Found.
# 2023-09-22 07:34:37 [INFO] idaes.init.fs.F102.control_volume.properties_out: State Released.
# 2023-09-22 07:34:37 [INFO] idaes.init.fs.F102.control_volume: Initialization Complete
# 2023-09-22 07:34:37 [INFO] idaes.init.fs.F102: Initialization Step 1 Complete.
# 2023-09-22 07:34:37 [DEBUG] idaes.solve.fs.F102: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: tol=1e-06
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: max_iter=200
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: ******************************************************************************
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:          For more information visit http://projects.coin-or.org/Ipopt
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: This version of Ipopt was compiled from source code available at
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:     for large-scale scientific computation.  All technical papers, sales and
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:     publicity material resulting from use of the HSL codes within IPOPT must
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:     contain the following acknowledgement:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:         HSL, a collection of Fortran codes for large-scale scientific
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:         computation. See http://www.hsl.rl.ac.uk.
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: ******************************************************************************
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of nonzeros in equality constraint Jacobian...:      124
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of nonzeros in inequality constraint Jacobian.:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of nonzeros in Lagrangian Hessian.............:      115
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Total number of variables............................:       41
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:                      variables with only lower bounds:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:                 variables with lower and upper bounds:        9
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:                      variables with only upper bounds:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Total number of equality constraints.................:       41
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Total number of inequality constraints...............:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:         inequality constraints with only lower bounds:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    inequality constraints with lower and upper bounds:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:         inequality constraints with only upper bounds:        0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    0  0.0000000e+00 9.03e+04 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    1  0.0000000e+00 3.70e+04 6.71e+00  -1.0 2.03e+04    -  9.90e-01 7.88e-01h  1
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    2  0.0000000e+00 7.96e+03 1.00e+02  -1.0 3.88e+03    -  8.89e-01 9.03e-01h  1
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    3  0.0000000e+00 4.57e+02 4.52e+04  -1.0 1.43e+03    -  9.12e-01 9.90e-01H  1
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    4  0.0000000e+00 1.81e+01 1.55e+04  -1.0 9.26e+01    -  9.91e-01 1.00e+00h  1
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    5  0.0000000e+00 6.31e-03 2.66e+02  -1.0 1.60e+00    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:    6  0.0000000e+00 2.59e-09 1.82e-02  -1.7 1.19e-03    -  1.00e+00 1.00e+00h  1
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of Iterations....: 6
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:                                    (scaled)                 (unscaled)
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Constraint violation....:   1.7905676941154525e-12    2.5902409106492996e-09
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Overall NLP error.......:   1.7905676941154525e-12    2.5902409106492996e-09
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of objective function evaluations             = 9
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of objective gradient evaluations             = 7
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of equality constraint evaluations            = 9
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of inequality constraint evaluations          = 0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of equality constraint Jacobian evaluations   = 7
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of inequality constraint Jacobian evaluations = 0
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Number of Lagrangian Hessian evaluations             = 6
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: Total CPU secs in NLP function evaluations           =      0.000
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102:
# 2023-09-22 07:34:38 [DEBUG] idaes.solve.fs.F102: EXIT: Optimal Solution Found.
# 2023-09-22 07:34:38 [INFO] idaes.init.fs.F102: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-09-22 07:34:38 [INFO] idaes.init.fs.F102.control_volume.properties_in: State Released.
# 2023-09-22 07:34:38 [INFO] idaes.init.fs.F102: Initialization Complete: optimal - Optimal Solution Found

# %% [markdown]
# <div class="alert alert-block alert-info">Since the FV is connected to the current state of the model in memory, simply hitting "Refresh" in the FV window will show the new flash unit in the diagram, and the new stream (liquid) in the stream table. We can then interactively rearrange the unit to be in the position we want in the diagram.</div>

# %%
# v model.fs.visualize("Hydrodealkylation-new")

# %% [markdown]
# ### Showing new values
# The previous step showed how a new unit in the flowsheet will be automatically added to the diagram. Similarly, if the values in the flowsheet change these will be reflected in the stream table. Below, we solve the initialized flowsheet.
# To make comparison a little easier, we will open a second UI window with the new values (the old values will not be updated unless we decide to hit the "Refresh" button).

# %% [markdown]
# When we look at the stream table, we can see the values in the stream between the first and second flash unit changing.

# %% [markdown]
# ## Running from a script
# Finally, although all examples have been shown in a Jupyter Notebook, there is nothing preventing the use of the FV from within a plain Python script (or module).
#
# For example, the code to run this same tutorial as a Python script is also in a module.
# If you have installed the IDAES examples, then you can do the following to import and run the module:
# ```
# from idaes_examples.mod.tut import visualizer_tutorial
# visualizer_tutorial.main()
# ```

# %% [markdown]
# # Further reading
#
# Reference documentation for the FV is available in the IDAES main documentation, online at https://idaes-ui.readthedocs.io/
