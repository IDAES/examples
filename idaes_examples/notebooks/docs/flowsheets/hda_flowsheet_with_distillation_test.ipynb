# %%
###############################################################################
# The Institute for the Design of Advanced Energy Systems Integrated Platform
# Framework (IDAES IP) was produced under the DOE Institute for the
# Design of Advanced Energy Systems (IDAES).
#
# Copyright (c) 2018-2023 by the software owners: The Regents of the
# University of California, through Lawrence Berkeley National Laboratory,
# National Technology & Engineering Solutions of Sandia, LLC, Carnegie Mellon
# University, West Virginia University Research Corporation, et al.
# All rights reserved.  Please see the files COPYRIGHT.md and LICENSE.md
# for full copyright and license information.
###############################################################################

# %% [markdown]
# # HDA Flowsheet Simulation and Optimization
#
#
# ## Note
#
# This tutorial will be similar to the HDA flowsheet tutorial in the Tutorials section, except that we use a distillation column instead of a second flash (F102) to produce benzene and toluene products.
#
#
# ## Learning outcomes
#
#
# - Construct a steady-state flowsheet using the IDAES unit model library
# - Connecting unit models in a  flowsheet using Arcs
# - Using the SequentialDecomposition tool to initialize a flowsheet with recycle
# - Fomulate and solve an optimization problem
#     - Defining an objective function
#     - Setting variable bounds
#     - Adding additional constraints
#
#
# ## Problem Statement
#
# Hydrodealkylation is a chemical reaction that often involves reacting
# an aromatic hydrocarbon in the presence of hydrogen gas to form a
# simpler aromatic hydrocarbon devoid of functional groups. In this
# example, toluene will be reacted with hydrogen gas at high temperatures
#  to form benzene via the following reaction:
#
# **C<sub>6</sub>H<sub>5</sub>CH<sub>3</sub> + H<sub>2</sub> → C<sub>6</sub>H<sub>6</sub> + CH<sub>4</sub>**
#
#
# This reaction is often accompanied by an equilibrium side reaction
# which forms diphenyl, which we will neglect for this example.
#
# This example is based on the 1967 AIChE Student Contest problem as
# present by Douglas, J.M., Chemical  Design of Chemical Processes, 1988,
# McGraw-Hill.
#
# The flowsheet that we will be using for this module is shown below with the stream conditions. We will be processing toluene and hydrogen to produce at least 370 TPY of benzene. As shown in the flowsheet, we use a flash tank, F101, to separate out the non-condensibles, and a distillation column, D101, to further separate the benzene-toluene mixture to improve the benzene purity.  The non-condensibles separated out in F101 will be partially recycled back to M101 and the rest will be purged. We will assume ideal gas behavior for this flowsheet. The properties required for this module are defined in
#
# - `hda_ideal_VLE.py`
# - `idaes.models.properties.activity_coeff_models.BTX_activity_coeff_VLE`
# - `hda_reaction.py`
#
# We will be using two thermodynamic packages: one (first in the list above) containing all four components (i.e., toluene, hydrogen, benzene, and methane) and the other (second in the list above) containing benzene and toluene only. The latter is needed to simplify the VLE calculations in the distillation column model.
#
# ![](HDA_flowsheet_distillation.png)

# %% [markdown]
# ## Translator block
#
# Benzene and toluene are separated by distillation, so the process involves phase equilibrium and two-phase flow conditions. However, the presence of hydrogen and methane complicates the calculations. This is because, hydrogen and methane are non-condensable under all conditions of interest; ergo, a vapor phase will always be present, and the mixture bubble point is extremely low. To simplify the phase equilibrium calculations, hydrogen and methane will be considered completely as non-condensable and insoluble in the liquid outlet from the flash F101.
#
# Since no hydrogen and methane will be present in the unit operations following the flash, a different component list can be used to simplify the property calculations. IDAES supports the definition of multiple property packages within a single flowsheet via `Translator` blocks. `Translator` blocks convert between different property calculations, component lists, and equations of state.

# %% [markdown]
# ## Importing required pyomo and idaes components
#
#
# To construct a flowsheet, we will need several components from the pyomo and idaes package. Let us first import the following components from Pyomo:
# - Constraint (to write constraints)
# - Var (to declare variables)
# - ConcreteModel (to create the concrete model object)
# - Expression (to evaluate values as a function of variables defined in the model)
# - Objective (to define an objective function for optimization)
# - SolverFactory (to solve the problem)
# - TransformationFactory (to apply certain transformations)
# - Arc (to connect two unit models)
# - SequentialDecomposition (to initialize the flowsheet in a sequential mode)
#
# For further details on these components, please refer to the pyomo documentation: https://pyomo.readthedocs.io/en/stable/

# %%
from pyomo.environ import (
    Constraint,
    Var,
    ConcreteModel,
    Expression,
    Objective,
    TransformationFactory,
    value,
)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Import `Arc` and `SequentialDecomposition` tools from `pyomo.network`
# </div>

# %%
# Todo: Import the above mentioned tools from pyomo.network
from pyomo.network import Arc, SequentialDecomposition

# %% [markdown]
# From IDAES, we will be needing the FlowsheetBlock and the following unit models:
# - Mixer
# - Heater
# - CSTR
# - Flash
# - Separator (splitter)
# - PressureChanger
# - Translator (to switch from one property package to another)
# - TrayColumn (distillation column)
# - CondenserType (Type of the overhead condenser: complete or partial)
# - TemperatureSpec (Temperature specification inside the condenser)

# %%
from idaes.core import FlowsheetBlock

# %%
from idaes.models.unit_models import (
    PressureChanger,
    Mixer,
    Separator as Splitter,
    Heater,
    CSTR,
    Flash,
    Translator,
)

from idaes.models_extra.column_models import TrayColumn
from idaes.models_extra.column_models.condenser import CondenserType, TemperatureSpec

# %% [markdown]
# We will also be needing some utility tools to put together the flowsheet and calculate the degrees of freedom.

# %%
# Utility tools to put together the flowsheet and calculate the degrees of freedom
from idaes.models.unit_models.pressure_changer import ThermodynamicAssumption
from idaes.core.util.model_statistics import degrees_of_freedom
from idaes.core.util.initialization import propagate_state
from idaes.core.solvers import get_solver
import idaes.core.util.scaling as iscale

# Import idaes logger to set output levels
import idaes.logger as idaeslog

# %% [markdown]
# ## Importing required thermo and reaction packages
#
# Finally, we import the thermophysical (`ideal_VLE.py` and `BTXParameterBlock`) packages and reaction package (`reaction.py`) for the HDA process. We have created custom thermophysical packages that assume ideal gas behavior with support for VLE. The reaction package consists of the stochiometric coefficients for the reaction, heat of reaction, and kinetic information (Arrhenius constant and activation energy).

# %%
from idaes_examples.mod.hda import hda_reaction as reaction_props
from idaes.models.properties.activity_coeff_models.BTX_activity_coeff_VLE import (
    BTXParameterBlock,
)

from idaes_examples.mod.hda.hda_ideal_VLE import HDAParameterBlock

# %% [markdown]
# ## Constructing the Flowsheet
#
# We have now imported all the components, unit models, and property modules we need to construct a flowsheet. Let us create a ConcreteModel and add the flowsheet block to it.

# %%
# Create a Pyomo Concrete Model to contain the problem
m = ConcreteModel()

# Add a steady state flowsheet block to the model
m.fs = FlowsheetBlock(dynamic=False)

# %% [markdown]
# We will now add the thermophysical and reaction packages to the flowsheet.

# %%
# Property package for benzene, toluene, hydrogen, methane mixture
m.fs.BTHM_params = HDAParameterBlock()

# Property package for the benzene-toluene mixture
m.fs.BT_params = BTXParameterBlock(
    valid_phase=("Liq", "Vap"), activity_coeff_model="Ideal"
)

# Reaction package for the HDA reaction
m.fs.reaction_params = reaction_props.HDAReactionParameterBlock(
    property_package=m.fs.BTHM_params
)
# Out:
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.pressure_crit' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.temperature_crit' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.mw_comp' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.dens_liq_param_1' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.dens_liq_param_2' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.dens_liq_param_3' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.dens_liq_param_4' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.temperature_boil' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.cp_ig_1' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.cp_ig_2' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.cp_ig_3' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.cp_ig_4' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.cp_ig_5' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.pressure_sat_coeff_A' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.pressure_sat_coeff_B' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.pressure_sat_coeff_C' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BTHM_params.dh_vap' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BT_params.pressure_critical' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BT_params.temperature_critical' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BT_params.mw_comp' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BT_params.dh_form' to mutable.
# WARNING: Params with units must be mutable.  Converting Param
# 'fs.BT_params.ds_form' to mutable.

# %% [markdown]
# ## Adding Unit Models
#
# Let us start adding the unit models we have imported to the flowsheet. Here, we are adding the Mixer (assigned a name M101) and a Heater (assigned a name H101). Note that, all unit models need to be given a property package argument. In addition, the Mixer unit model needs a `list` consisting of the inlets (toluene feed, hydrogen feed and vapor recycle streams in this case).

# %%
# Adding the mixer M101 to the flowsheet
m.fs.M101 = Mixer(
    property_package=m.fs.BTHM_params,
    inlet_list=["toluene_feed", "hydrogen_feed", "vapor_recycle"],
)

# Adding the heater H101 to the flowsheet
m.fs.H101 = Heater(property_package=m.fs.BTHM_params, has_phase_equilibrium=True)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Let us now add the CSTR (assign the name R101) and pass the following arguments:
#       <ul>
#          <li>"property_package": m.fs.BTHM_params</li>
#          <li>"reaction_package": m.fs.reaction_params </li>
#          <li>"has_heat_of_reaction": True </li>
#          <li>"has_heat_transfer": True</li>
#       </ul>
# </div>

# %%
# Todo: Add reactor with the specifications above
m.fs.R101 = CSTR(
    property_package=m.fs.BTHM_params,
    reaction_package=m.fs.reaction_params,
    has_heat_of_reaction=True,
    has_heat_transfer=True,
)

# %% [markdown]
# Let us now add the Flash (assign the name F101), Splitter (assign the name S101) and PressureChanger (assign the name C101)

# %%
# Adding the flash tank F101 to the flowsheet
m.fs.F101 = Flash(
    property_package=m.fs.BTHM_params, has_heat_transfer=True, has_pressure_change=True
)

# Adding the splitter S101 to the flowsheet
m.fs.S101 = Splitter(
    property_package=m.fs.BTHM_params, outlet_list=["purge", "recycle"]
)

# Adding the compressor C101 to the flowsheet
m.fs.C101 = PressureChanger(
    property_package=m.fs.BTHM_params,
    compressor=True,
    thermodynamic_assumption=ThermodynamicAssumption.isothermal,
)

# %% [markdown]
# ## Remark
#
# Currently, the `SequentialDecomposition()` tool, which we will later be using to initialize the flowsheet, does not support the distillation column model. Thus, we will first simulate the flowsheet without the distillation column. After it converges, we will then add the distillation column, initialize it, and simulate the entire flowsheet.

# %% [markdown]
# As mentioned above, we use the `m.fs.BTHM_params` package, which contains all the four species, for the reactor loop, and the simpler `m.fs.BT_params` for unit operations following the flash (i.e., heater H102 and the distillation column D101). We define a `Translator` block to link the source property package and the package it is to be translated to in the following manner:

# %%
# Add translator block to convert between property packages
m.fs.translator = Translator(
    inlet_property_package=m.fs.BTHM_params, outlet_property_package=m.fs.BT_params
)

# %% [markdown]
# ### Translator block constraints
#
# The `Translator` block needs to know how to translate between the two property packages. This must be custom coded for each application because of the generality of the IDAES framework.
#
# For this process, five constraints are required based on the state variables used in the outgoing process.
#
# - Since we assumed that only benzene and toluene are present in the liquid phase, the total molar flowrate must be the sum of molar flowrates of benzene and toluene, respectively.
# - Temperature of the inlet and outlet streams must be the same.
# - Pressure of the inlet and outgoing streams must be the same
# - The mole fraction of benzene in the outgoing stream is the ratio of the molar flowrate of liquid benzene in the inlet to the sum of molar flowrates of liquid benzene and toluene in the inlet.
# - The mole fraction of toluene in the outgoing stream is the ratio of the molar flowrate of liquid toluene in the inlet to the sum of molar flowrates of liquid benzene and toluene in the inlet.

# %%
# Add constraint: Total flow = benzene flow + toluene flow (molar)
m.fs.translator.eq_total_flow = Constraint(
    expr=m.fs.translator.outlet.flow_mol[0]
    == m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "benzene"]
    + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "toluene"]
)

# Add constraint: Outlet temperature = Inlet temperature
m.fs.translator.eq_temperature = Constraint(
    expr=m.fs.translator.outlet.temperature[0] == m.fs.translator.inlet.temperature[0]
)

# %% [markdown]
# In the above, note that the variable flow_mol_phase_comp has the index - [time, phase, component]. As this is a steady-state flowsheet, the time index by default is 0. The valid phases are ["Liq", "Vap"]. Similarly the valid component list is ["benzene", "toluene", "hydrogen", "methane"].

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Add the constraint to ensure that the outlet pressure is the same as the inlet pressure
# </div>

# %%
# Todo: Add constraint: Outlet pressure = Inlet pressure
m.fs.translator.eq_pressure = Constraint(
    expr=m.fs.translator.outlet.pressure[0] == m.fs.translator.inlet.pressure[0]
)

# %%
# Remaining constraints on the translator block

# Add constraint: Benzene mole fraction definition
m.fs.translator.eq_mole_frac_benzene = Constraint(
    expr=m.fs.translator.outlet.mole_frac_comp[0, "benzene"]
    == m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "benzene"]
    / (
        m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "benzene"]
        + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "toluene"]
        + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "hydrogen"]
        + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "methane"]
    )
)

# Add constraint: Toluene mole fraction definition
m.fs.translator.eq_mole_frac_toluene = Constraint(
    expr=m.fs.translator.outlet.mole_frac_comp[0, "toluene"]
    == m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "toluene"]
    / (
        m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "benzene"]
        + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "toluene"]
                + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "hydrogen"]
        + m.fs.translator.inlet.flow_mol_phase_comp[0, "Liq", "methane"]
    )
)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Finally, let us add the Heater H102 in the same way as H101 but pass the m.fs.BT_params thermodynamic package. We will add the distillation column after converging the flowsheet.
# </div>

# %%
# Todo: Add the Heater H102 to the flowsheet
m.fs.H102 = Heater(
    property_package=m.fs.BT_params,
    has_pressure_change=True,
    has_phase_equilibrium=True,
)

# %%
m.fs.H102.pprint()
# Out:
# H102 : Size=1, Index=None, Active=True
#     10 Var Declarations
#         _flow_mol_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.properties_in[...].component('flow_mol')
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :   1.0 :  None : False : False : NonNegativeReals
#         _flow_mol_outlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.properties_out[...].component('flow_mol')
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :   1.0 :  None : False : False : NonNegativeReals
#         _mole_frac_comp_inlet_ref : Size=2, Index=fs._time*fs.BT_params.component_list, ReferenceTo=fs.H102.control_volume.properties_in[...].component('mole_frac_comp')[...]
#             Key              : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#             (0.0, 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#         _mole_frac_comp_outlet_ref : Size=2, Index=fs._time*fs.BT_params.component_list, ReferenceTo=fs.H102.control_volume.properties_out[...].component('mole_frac_comp')[...]
#             Key              : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#             (0.0, 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#         _pressure_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.properties_in[...].component('pressure')
#             Key : Lower : Value  : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 101325 :  None : False : False : NonNegativeReals
#         _pressure_outlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.properties_out[...].component('pressure')
#             Key : Lower : Value  : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 101325 :  None : False : False : NonNegativeReals
#         _temperature_inlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.properties_in[...].component('temperature')
#             Key : Lower : Value  : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 298.15 :  None : False : False : NonNegativeReals
#         _temperature_outlet_ref : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.properties_out[...].component('temperature')
#             Key : Lower : Value  : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 298.15 :  None : False : False : NonNegativeReals
#         deltaP : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.deltaP
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   0.0 :  None : False : False :  Reals
#         heat_duty : Size=1, Index=fs._time, ReferenceTo=fs.H102.control_volume.heat
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   0.0 :  None : False : False :  Reals
#
#     1 Block Declarations
#         control_volume : Size=1, Index=None, Active=True
#             2 Var Declarations
#                 deltaP : Pressure difference across unit
#                     Size=1, Index=fs._time, Units=kg/m/s**2
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :  None :   0.0 :  None : False : False :  Reals
#                 heat : Heat transferred into control volume
#                     Size=1, Index=fs._time, Units=kg*m**2/s**3
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                     0.0 :  None :   0.0 :  None : False : False :  Reals
#
#             3 Constraint Declarations
#                 enthalpy_balances : Energy balances
#                     Size=1, Index=fs._time, Active=True
#                     Key : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   : Upper : Active
#                     0.0 :   0.0 : (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].enth_mol_phase[Liq]) + (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].enth_mol_phase[Vap]) - ((fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_out[0.0].enth_mol_phase[Liq]) + (fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_out[0.0].enth_mol_phase[Vap])) + fs.H102.control_volume.heat[0.0] :   0.0 :   True
#                 material_balances : Material balances
#                     Size=2, Index=fs._time*fs.BT_params.component_list, Active=True
#                     Key              : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        : Upper : Active
#                     (0.0, 'benzene') :   0.0 : (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]) + (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]) - ((fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,benzene]) + (fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,benzene])) :   0.0 :   True
#                     (0.0, 'toluene') :   0.0 : (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]) + (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) - ((fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,toluene]) + (fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,toluene])) :   0.0 :   True
#                 pressure_balance : Momentum balance
#                     Size=1, Index=fs._time, Active=True
#                     Key : Lower : Body                                                                                                                                          : Upper : Active
#                     0.0 :   0.0 : fs.H102.control_volume.properties_in[0.0].pressure - fs.H102.control_volume.properties_out[0.0].pressure + fs.H102.control_volume.deltaP[0.0] :   0.0 :   True
#
#             2 Block Declarations
#                 properties_in : Material properties at inlet
#                     Size=1, Index=fs._time, Active=True
#                     fs.H102.control_volume.properties_in[0.0] : Active=True
#                         2 Param Declarations
#                             eps_1 : Smoothing parameter for equilibrium temperature
#                                 Size=1, Index=None, Domain=Any, Default=0.01, Mutable=True, Units=K
#                                 Key : Value
#                             eps_2 : Smoothing parameter for equilibrium temperature
#                                 Size=1, Index=None, Domain=Any, Default=0.0005, Mutable=True, Units=K
#                                 Key : Value
#
#                         13 Var Declarations
#                             _t1 : Intermediate temperature for calculating the equilibrium temperature
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#                             _temperature_equilibrium : Temperature for calculating phase equilibrium
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#                             enth_mol_phase : Phase molar specific enthalpies [J/mol]
#                                 Size=2, Index=fs.BT_params.phase_list, Units=J/mol
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 Liq :  None :  None :  None : False :  True :  Reals
#                                 Vap :  None :  None :  None : False :  True :  Reals
#                             enth_mol_phase_comp : Phase-component molar specific enthalpies [J/mol]
#                                 Size=4, Index=fs.BT_params._phase_component_set, Units=J/mol
#                                 Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                 ('Liq', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                 ('Liq', 'toluene') :  None :  None :  None : False :  True :  Reals
#                                 ('Vap', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                 ('Vap', 'toluene') :  None :  None :  None : False :  True :  Reals
#                             flow_mol : Total molar flowrate [mol/s]
#                                 Size=1, Index=None, Units=mol/s
#                                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                                 None :     0 :   1.0 :  None : False : False : NonNegativeReals
#                             flow_mol_phase : Size=2, Index=fs.BT_params.phase_list, Units=mol/s
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 Liq :  None :   0.5 :  None : False : False :  Reals
#                                 Vap :  None :   0.5 :  None : False : False :  Reals
#                             mole_frac_comp : Mixture mole fraction
#                                 Size=2, Index=fs.BT_params.component_list
#                                 Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                                 benzene :     0 :   0.5 :     1 : False : False :  Reals
#                                 toluene :     0 :   0.5 :     1 : False : False :  Reals
#                             mole_frac_phase_comp : Size=4, Index=fs.BT_params._phase_component_set
#                                 Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                 ('Liq', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 ('Liq', 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 ('Vap', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 ('Vap', 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                             pressure : State pressure [Pa]
#                                 Size=1, Index=None, Units=Pa
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :     0 : 101325 :  None : False : False : NonNegativeReals
#                             pressure_sat_comp : vapor pressure
#                                 Size=2, Index=fs.BT_params.component_list, Units=Pa
#                                 Key     : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 benzene :  None : 101325 :  None : False : False :  Reals
#                                 toluene :  None : 101325 :  None : False : False :  Reals
#                             temperature : State temperature [K]
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :     0 : 298.15 :  None : False : False : NonNegativeReals
#                             temperature_bubble : Bubble point temperature (K)
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#                             temperature_dew : Dew point temperature (K)
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#
#                         6 Expression Declarations
#                             _p_sat_bubbleT : Size=2, Index=fs.BT_params.component_list
#                                 Key     : Expression
#                                 benzene : fs.BT_params.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble) + 1.33213*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.62863*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**3 - 3.33399*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)))
#                                 toluene : fs.BT_params.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble) + 1.38091*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.83433*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**3 - 2.79168*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)))
#                             _p_sat_dewT : Size=2, Index=fs.BT_params.component_list
#                                 Key     : Expression
#                                 benzene : fs.BT_params.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew) + 1.33213*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.62863*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**3 - 3.33399*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)))
#                                 toluene : fs.BT_params.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew) + 1.38091*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.83433*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**3 - 2.79168*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)))
#                             _reduced_temp : Size=2, Index=fs.BT_params.component_list
#                                 Key     : Expression
#                                 benzene : (fs.BT_params.temperature_critical[benzene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[benzene]
#                                 toluene : (fs.BT_params.temperature_critical[toluene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[toluene]
#                             enthalpy_flow_terms : Size=2, Index=fs.BT_params.phase_list
#                                 Key : Expression
#                                 Liq : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].enth_mol_phase[Liq]
#                                 Vap : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].enth_mol_phase[Vap]
#                             fug_phase_comp : Size=4, Index=fs.BT_params.phase_list*fs.BT_params.component_list
#                                 Key                : Expression
#                                 ('Liq', 'benzene') : fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]*fs.H102.control_volume.properties_in[0.0].pressure_sat_comp[benzene]
#                                 ('Liq', 'toluene') : fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]*fs.H102.control_volume.properties_in[0.0].pressure_sat_comp[toluene]
#                                 ('Vap', 'benzene') :                   fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]*fs.H102.control_volume.properties_in[0.0].pressure
#                                 ('Vap', 'toluene') :                   fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]*fs.H102.control_volume.properties_in[0.0].pressure
#                             material_flow_terms : Size=4, Index=fs.BT_params.phase_list*fs.BT_params.component_list
#                                 Key                : Expression
#                                 ('Liq', 'benzene') : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]
#                                 ('Liq', 'toluene') : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]
#                                 ('Vap', 'benzene') : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]
#                                 ('Vap', 'toluene') : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]
#
#                         11 Constraint Declarations
#                             _t1_constraint : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                              : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_in[0.0]._t1 - 0.5*(fs.H102.control_volume.properties_in[0.0].temperature + fs.H102.control_volume.properties_in[0.0].temperature_bubble + sqrt((fs.H102.control_volume.properties_in[0.0].temperature - fs.H102.control_volume.properties_in[0.0].temperature_bubble)**2 + fs.H102.control_volume.properties_in[0.0].eps_1**2)) :   0.0 :   True
#                             _teq_constraint : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                             : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium - 0.5*(fs.H102.control_volume.properties_in[0.0]._t1 + fs.H102.control_volume.properties_in[0.0].temperature_dew - sqrt((fs.H102.control_volume.properties_in[0.0]._t1 - fs.H102.control_volume.properties_in[0.0].temperature_dew)**2 + fs.H102.control_volume.properties_in[0.0].eps_2**2)) :   0.0 :   True
#                             eq_P_vap : Size=2, Index=fs.BT_params.component_list, Active=True
#                                 Key     : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       : Upper : Active
#                                 benzene :   0.0 : (1 - ((fs.BT_params.temperature_critical[benzene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[benzene]))*log(1/fs.BT_params.pressure_critical[benzene]*fs.H102.control_volume.properties_in[0.0].pressure_sat_comp[benzene]) - (-6.98273*((fs.BT_params.temperature_critical[benzene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[benzene]) + 1.33213*((fs.BT_params.temperature_critical[benzene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[benzene])**1.5 - 2.62863*((fs.BT_params.temperature_critical[benzene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[benzene])**3 - 3.33399*((fs.BT_params.temperature_critical[benzene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[benzene])**6) :   0.0 :   True
#                                 toluene :   0.0 : (1 - ((fs.BT_params.temperature_critical[toluene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[toluene]))*log(1/fs.BT_params.pressure_critical[toluene]*fs.H102.control_volume.properties_in[0.0].pressure_sat_comp[toluene]) - (-7.28607*((fs.BT_params.temperature_critical[toluene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[toluene]) + 1.38091*((fs.BT_params.temperature_critical[toluene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[toluene])**1.5 - 2.83433*((fs.BT_params.temperature_critical[toluene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[toluene])**3 - 2.79168*((fs.BT_params.temperature_critical[toluene] - fs.H102.control_volume.properties_in[0.0]._temperature_equilibrium)/fs.BT_params.temperature_critical[toluene])**6) :   0.0 :   True
#                             eq_comp : Size=2, Index=fs.BT_params.component_list, Active=True
#                                 Key     : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                           : Upper : Active
#                                 benzene :   0.0 : fs.H102.control_volume.properties_in[0.0].flow_mol*fs.H102.control_volume.properties_in[0.0].mole_frac_comp[benzene] - (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene] + fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]) :   0.0 :   True
#                                 toluene :   0.0 : fs.H102.control_volume.properties_in[0.0].flow_mol*fs.H102.control_volume.properties_in[0.0].mole_frac_comp[toluene] - (fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene] + fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                             eq_enth_mol_phase : Size=2, Index=fs.BT_params.phase_list, Active=True
#                                 Key : Lower : Body                                                                                                                                                                                                                                                                                                                                                                              : Upper : Active
#                                 Liq :   0.0 : fs.H102.control_volume.properties_in[0.0].enth_mol_phase[Liq] - (fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,benzene]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene] + fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,toluene]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]) :   0.0 :   True
#                                 Vap :   0.0 : fs.H102.control_volume.properties_in[0.0].enth_mol_phase[Vap] - (fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,benzene]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene] + fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,toluene]*fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                             eq_enth_mol_phase_comp : Size=4, Index=fs.BT_params._phase_component_set, Active=True
#                                 Key                : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 : Upper : Active
#                                 ('Liq', 'benzene') :   0.0 : fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,benzene] - (fs.BT_params.dh_form[Liq,benzene] + 0.001*(kmol/mol)*(fs.BT_params.cp_mol_liq_comp_coeff_E[benzene]/5*(fs.H102.control_volume.properties_in[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_liq_comp_coeff_D[benzene]/4*(fs.H102.control_volume.properties_in[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_liq_comp_coeff_C[benzene]/3*(fs.H102.control_volume.properties_in[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_liq_comp_coeff_B[benzene]/2*(fs.H102.control_volume.properties_in[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_liq_comp_coeff_A[benzene]*(fs.H102.control_volume.properties_in[0.0].temperature - fs.BT_params.temperature_reference))) :   0.0 :   True
#                                 ('Liq', 'toluene') :   0.0 : fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,toluene] - (fs.BT_params.dh_form[Liq,toluene] + 0.001*(kmol/mol)*(fs.BT_params.cp_mol_liq_comp_coeff_E[toluene]/5*(fs.H102.control_volume.properties_in[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_liq_comp_coeff_D[toluene]/4*(fs.H102.control_volume.properties_in[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_liq_comp_coeff_C[toluene]/3*(fs.H102.control_volume.properties_in[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_liq_comp_coeff_B[toluene]/2*(fs.H102.control_volume.properties_in[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_liq_comp_coeff_A[toluene]*(fs.H102.control_volume.properties_in[0.0].temperature - fs.BT_params.temperature_reference))) :   0.0 :   True
#                                 ('Vap', 'benzene') :   0.0 :                    fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,benzene] - (fs.BT_params.cp_mol_vap_comp_coeff_E[benzene]/5*(fs.H102.control_volume.properties_in[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_vap_comp_coeff_D[benzene]/4*(fs.H102.control_volume.properties_in[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_vap_comp_coeff_C[benzene]/3*(fs.H102.control_volume.properties_in[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_vap_comp_coeff_B[benzene]/2*(fs.H102.control_volume.properties_in[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_vap_comp_coeff_A[benzene]*(fs.H102.control_volume.properties_in[0.0].temperature - fs.BT_params.temperature_reference) + fs.BT_params.dh_form[Vap,benzene]) :   0.0 :   True
#                                 ('Vap', 'toluene') :   0.0 :                    fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,toluene] - (fs.BT_params.cp_mol_vap_comp_coeff_E[toluene]/5*(fs.H102.control_volume.properties_in[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_vap_comp_coeff_D[toluene]/4*(fs.H102.control_volume.properties_in[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_vap_comp_coeff_C[toluene]/3*(fs.H102.control_volume.properties_in[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_vap_comp_coeff_B[toluene]/2*(fs.H102.control_volume.properties_in[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_vap_comp_coeff_A[toluene]*(fs.H102.control_volume.properties_in[0.0].temperature - fs.BT_params.temperature_reference) + fs.BT_params.dh_form[Vap,toluene]) :   0.0 :   True
#                             eq_phase_equilibrium : Size=2, Index=fs.BT_params.component_list, Active=True
#                                 Key     : Lower : Body                                                                                                                                                                                                                                                                                  : Upper : Active
#                                 benzene :   0.0 : (fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene]*fs.H102.control_volume.properties_in[0.0].pressure) - (fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene]*fs.H102.control_volume.properties_in[0.0].pressure_sat_comp[benzene]) :   0.0 :   True
#                                 toluene :   0.0 : (fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]*fs.H102.control_volume.properties_in[0.0].pressure) - (fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene]*fs.H102.control_volume.properties_in[0.0].pressure_sat_comp[toluene]) :   0.0 :   True
#                             eq_sum_mol_frac : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                    : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,benzene] + fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Liq,toluene] - (fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,benzene] + fs.H102.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                             eq_temperature_bubble : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_in[0.0].mole_frac_comp[benzene]*(fs.BT_params.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble) + 1.33213*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.62863*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**3 - 3.33399*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)))) + fs.H102.control_volume.properties_in[0.0].mole_frac_comp[toluene]*(fs.BT_params.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble) + 1.38091*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**1.5 - 2.83433*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**3 - 2.79168*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_bubble)))) - fs.H102.control_volume.properties_in[0.0].pressure :   0.0 :   True
#                             eq_temperature_dew : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_in[0.0].pressure*(fs.H102.control_volume.properties_in[0.0].mole_frac_comp[benzene]/(fs.BT_params.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew) + 1.33213*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.62863*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**3 - 3.33399*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)))) + fs.H102.control_volume.properties_in[0.0].mole_frac_comp[toluene]/(fs.BT_params.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew) + 1.38091*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**1.5 - 2.83433*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**3 - 2.79168*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_in[0.0].temperature_dew))))) - 1 :   0.0 :   True
#                             eq_total : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                               : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Liq] + fs.H102.control_volume.properties_in[0.0].flow_mol_phase[Vap] - fs.H102.control_volume.properties_in[0.0].flow_mol :   0.0 :   True
#
#                         32 Declarations: flow_mol mole_frac_comp pressure temperature flow_mol_phase mole_frac_phase_comp eq_total eq_comp eq_sum_mol_frac _temperature_equilibrium _t1 eps_1 eps_2 _t1_constraint temperature_bubble _p_sat_bubbleT eq_temperature_bubble _teq_constraint temperature_dew _p_sat_dewT eq_temperature_dew eq_phase_equilibrium fug_phase_comp pressure_sat_comp _reduced_temp eq_P_vap material_flow_terms enthalpy_flow_terms enth_mol_phase eq_enth_mol_phase enth_mol_phase_comp eq_enth_mol_phase_comp
#                 properties_out : Material properties at outlet
#                     Size=1, Index=fs._time, Active=True
#                     fs.H102.control_volume.properties_out[0.0] : Active=True
#                         2 Param Declarations
#                             eps_1 : Smoothing parameter for equilibrium temperature
#                                 Size=1, Index=None, Domain=Any, Default=0.01, Mutable=True, Units=K
#                                 Key : Value
#                             eps_2 : Smoothing parameter for equilibrium temperature
#                                 Size=1, Index=None, Domain=Any, Default=0.0005, Mutable=True, Units=K
#                                 Key : Value
#
#                         13 Var Declarations
#                             _t1 : Intermediate temperature for calculating the equilibrium temperature
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#                             _temperature_equilibrium : Temperature for calculating phase equilibrium
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#                             enth_mol_phase : Phase molar specific enthalpies [J/mol]
#                                 Size=2, Index=fs.BT_params.phase_list, Units=J/mol
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 Liq :  None :  None :  None : False :  True :  Reals
#                                 Vap :  None :  None :  None : False :  True :  Reals
#                             enth_mol_phase_comp : Phase-component molar specific enthalpies [J/mol]
#                                 Size=4, Index=fs.BT_params._phase_component_set, Units=J/mol
#                                 Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                 ('Liq', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                 ('Liq', 'toluene') :  None :  None :  None : False :  True :  Reals
#                                 ('Vap', 'benzene') :  None :  None :  None : False :  True :  Reals
#                                 ('Vap', 'toluene') :  None :  None :  None : False :  True :  Reals
#                             flow_mol : Total molar flowrate [mol/s]
#                                 Size=1, Index=None, Units=mol/s
#                                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                                 None :     0 :   1.0 :  None : False : False : NonNegativeReals
#                             flow_mol_phase : Size=2, Index=fs.BT_params.phase_list, Units=mol/s
#                                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                                 Liq :  None :   0.5 :  None : False : False :  Reals
#                                 Vap :  None :   0.5 :  None : False : False :  Reals
#                             mole_frac_comp : Mixture mole fraction
#                                 Size=2, Index=fs.BT_params.component_list
#                                 Key     : Lower : Value : Upper : Fixed : Stale : Domain
#                                 benzene :     0 :   0.5 :     1 : False : False :  Reals
#                                 toluene :     0 :   0.5 :     1 : False : False :  Reals
#                             mole_frac_phase_comp : Size=4, Index=fs.BT_params._phase_component_set
#                                 Key                : Lower : Value : Upper : Fixed : Stale : Domain
#                                 ('Liq', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 ('Liq', 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 ('Vap', 'benzene') :     0 :   0.5 :     1 : False : False :  Reals
#                                 ('Vap', 'toluene') :     0 :   0.5 :     1 : False : False :  Reals
#                             pressure : State pressure [Pa]
#                                 Size=1, Index=None, Units=Pa
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :     0 : 101325 :  None : False : False : NonNegativeReals
#                             pressure_sat_comp : vapor pressure
#                                 Size=2, Index=fs.BT_params.component_list, Units=Pa
#                                 Key     : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 benzene :  None : 101325 :  None : False : False :  Reals
#                                 toluene :  None : 101325 :  None : False : False :  Reals
#                             temperature : State temperature [K]
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :     0 : 298.15 :  None : False : False : NonNegativeReals
#                             temperature_bubble : Bubble point temperature (K)
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#                             temperature_dew : Dew point temperature (K)
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                                 None :  None : 298.15 :  None : False : False :  Reals
#
#                         6 Expression Declarations
#                             _p_sat_bubbleT : Size=2, Index=fs.BT_params.component_list
#                                 Key     : Expression
# ...
#                                 ('Liq', 'benzene') :   0.0 : fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Liq,benzene] - (fs.BT_params.dh_form[Liq,benzene] + 0.001*(kmol/mol)*(fs.BT_params.cp_mol_liq_comp_coeff_E[benzene]/5*(fs.H102.control_volume.properties_out[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_liq_comp_coeff_D[benzene]/4*(fs.H102.control_volume.properties_out[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_liq_comp_coeff_C[benzene]/3*(fs.H102.control_volume.properties_out[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_liq_comp_coeff_B[benzene]/2*(fs.H102.control_volume.properties_out[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_liq_comp_coeff_A[benzene]*(fs.H102.control_volume.properties_out[0.0].temperature - fs.BT_params.temperature_reference))) :   0.0 :   True
#                                 ('Liq', 'toluene') :   0.0 : fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Liq,toluene] - (fs.BT_params.dh_form[Liq,toluene] + 0.001*(kmol/mol)*(fs.BT_params.cp_mol_liq_comp_coeff_E[toluene]/5*(fs.H102.control_volume.properties_out[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_liq_comp_coeff_D[toluene]/4*(fs.H102.control_volume.properties_out[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_liq_comp_coeff_C[toluene]/3*(fs.H102.control_volume.properties_out[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_liq_comp_coeff_B[toluene]/2*(fs.H102.control_volume.properties_out[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_liq_comp_coeff_A[toluene]*(fs.H102.control_volume.properties_out[0.0].temperature - fs.BT_params.temperature_reference))) :   0.0 :   True
#                                 ('Vap', 'benzene') :   0.0 :                    fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Vap,benzene] - (fs.BT_params.cp_mol_vap_comp_coeff_E[benzene]/5*(fs.H102.control_volume.properties_out[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_vap_comp_coeff_D[benzene]/4*(fs.H102.control_volume.properties_out[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_vap_comp_coeff_C[benzene]/3*(fs.H102.control_volume.properties_out[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_vap_comp_coeff_B[benzene]/2*(fs.H102.control_volume.properties_out[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_vap_comp_coeff_A[benzene]*(fs.H102.control_volume.properties_out[0.0].temperature - fs.BT_params.temperature_reference) + fs.BT_params.dh_form[Vap,benzene]) :   0.0 :   True
#                                 ('Vap', 'toluene') :   0.0 :                    fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Vap,toluene] - (fs.BT_params.cp_mol_vap_comp_coeff_E[toluene]/5*(fs.H102.control_volume.properties_out[0.0].temperature**5 - fs.BT_params.temperature_reference**5) + fs.BT_params.cp_mol_vap_comp_coeff_D[toluene]/4*(fs.H102.control_volume.properties_out[0.0].temperature**4 - fs.BT_params.temperature_reference**4) + fs.BT_params.cp_mol_vap_comp_coeff_C[toluene]/3*(fs.H102.control_volume.properties_out[0.0].temperature**3 - fs.BT_params.temperature_reference**3) + fs.BT_params.cp_mol_vap_comp_coeff_B[toluene]/2*(fs.H102.control_volume.properties_out[0.0].temperature**2 - fs.BT_params.temperature_reference**2) + fs.BT_params.cp_mol_vap_comp_coeff_A[toluene]*(fs.H102.control_volume.properties_out[0.0].temperature - fs.BT_params.temperature_reference) + fs.BT_params.dh_form[Vap,toluene]) :   0.0 :   True
#                             eq_mol_frac_out : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                    : Upper : Active
#                                 None :   1.0 : fs.H102.control_volume.properties_out[0.0].mole_frac_comp[benzene] + fs.H102.control_volume.properties_out[0.0].mole_frac_comp[toluene] :   1.0 :   True
#                             eq_phase_equilibrium : Size=2, Index=fs.BT_params.component_list, Active=True
#                                 Key     : Lower : Body                                                                                                                                                                                                                                                                                      : Upper : Active
#                                 benzene :   0.0 : (fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,benzene]*fs.H102.control_volume.properties_out[0.0].pressure) - (fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,benzene]*fs.H102.control_volume.properties_out[0.0].pressure_sat_comp[benzene]) :   0.0 :   True
#                                 toluene :   0.0 : (fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,toluene]*fs.H102.control_volume.properties_out[0.0].pressure) - (fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,toluene]*fs.H102.control_volume.properties_out[0.0].pressure_sat_comp[toluene]) :   0.0 :   True
#                             eq_sum_mol_frac : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                        : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,benzene] + fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Liq,toluene] - (fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,benzene] + fs.H102.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#                             eq_temperature_bubble : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_out[0.0].mole_frac_comp[benzene]*(fs.BT_params.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble) + 1.33213*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)**1.5 - 2.62863*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)**3 - 3.33399*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)))) + fs.H102.control_volume.properties_out[0.0].mole_frac_comp[toluene]*(fs.BT_params.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble) + 1.38091*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)**1.5 - 2.83433*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)**3 - 2.79168*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_bubble)))) - fs.H102.control_volume.properties_out[0.0].pressure :   0.0 :   True
#                             eq_temperature_dew : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_out[0.0].pressure*(fs.H102.control_volume.properties_out[0.0].mole_frac_comp[benzene]/(fs.BT_params.pressure_critical[benzene]*exp((-6.98273*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_dew) + 1.33213*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)**1.5 - 2.62863*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)**3 - 3.33399*(1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[benzene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)))) + fs.H102.control_volume.properties_out[0.0].mole_frac_comp[toluene]/(fs.BT_params.pressure_critical[toluene]*exp((-7.28607*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_dew) + 1.38091*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)**1.5 - 2.83433*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)**3 - 2.79168*(1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_dew)**6)/(1 - (1 - 1/fs.BT_params.temperature_critical[toluene]*fs.H102.control_volume.properties_out[0.0].temperature_dew))))) - 1 :   0.0 :   True
#                             eq_total : Size=1, Index=None, Active=True
#                                 Key  : Lower : Body                                                                                                                                                                                  : Upper : Active
#                                 None :   0.0 : fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Liq] + fs.H102.control_volume.properties_out[0.0].flow_mol_phase[Vap] - fs.H102.control_volume.properties_out[0.0].flow_mol :   0.0 :   True
#
#                         33 Declarations: flow_mol mole_frac_comp pressure temperature flow_mol_phase mole_frac_phase_comp eq_total eq_comp eq_sum_mol_frac eq_mol_frac_out _temperature_equilibrium _t1 eps_1 eps_2 _t1_constraint temperature_bubble _p_sat_bubbleT eq_temperature_bubble _teq_constraint temperature_dew _p_sat_dewT eq_temperature_dew eq_phase_equilibrium fug_phase_comp pressure_sat_comp _reduced_temp eq_P_vap material_flow_terms enthalpy_flow_terms enth_mol_phase eq_enth_mol_phase enth_mol_phase_comp eq_enth_mol_phase_comp
#
#             7 Declarations: properties_in properties_out material_balances heat enthalpy_balances deltaP pressure_balance
#
#     2 Port Declarations
#         inlet : Inlet Port
#             Size=1, Index=None
#             Key  : Name           : Size : Variable
#             None :       flow_mol :    1 :       fs.H102._flow_mol_inlet_ref
#                  : mole_frac_comp :    2 : fs.H102._mole_frac_comp_inlet_ref
#                  :       pressure :    1 :       fs.H102._pressure_inlet_ref
#                  :    temperature :    1 :    fs.H102._temperature_inlet_ref
#         outlet : Outlet Port
#             Size=1, Index=None
#             Key  : Name           : Size : Variable
#             None :       flow_mol :    1 :       fs.H102._flow_mol_outlet_ref
#                  : mole_frac_comp :    2 : fs.H102._mole_frac_comp_outlet_ref
#                  :       pressure :    1 :       fs.H102._pressure_outlet_ref
#                  :    temperature :    1 :    fs.H102._temperature_outlet_ref
#
#     13 Declarations: control_volume inlet _flow_mol_inlet_ref _mole_frac_comp_inlet_ref _temperature_inlet_ref _pressure_inlet_ref outlet _flow_mol_outlet_ref _mole_frac_comp_outlet_ref _temperature_outlet_ref _pressure_outlet_ref heat_duty deltaP

# %% [markdown]
# ## Connecting Unit Models using Arcs
#
# We have now added the initial set of unit models to the flowsheet. However, we have not yet specifed how the units are connected. To do this, we will be using the `Arc` which is a pyomo component that takes in two arguments: `source` and `destination`. Let us connect the outlet of the mixer (M101) to the inlet of the heater (H101).

# %%
m.fs.s03 = Arc(source=m.fs.M101.outlet, destination=m.fs.H101.inlet)

# %% [markdown]
# ![](HDA_flowsheet_distillation.png)
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Now, connect the H101 outlet to the R101 inlet using the cell above as a guide.
# </div>

# %%
# Todo: Connect the H101 outlet to R101 inlet
m.fs.s04 = Arc(source=m.fs.H101.outlet, destination=m.fs.R101.inlet)

# %% [markdown]
# We will now be connecting the rest of the units as shown below. Notice how the outlet names are different for the flash tank as it has a vapor and a liquid outlet.

# %%
m.fs.s05 = Arc(source=m.fs.R101.outlet, destination=m.fs.F101.inlet)
m.fs.s06 = Arc(source=m.fs.F101.vap_outlet, destination=m.fs.S101.inlet)
m.fs.s08 = Arc(source=m.fs.S101.recycle, destination=m.fs.C101.inlet)
m.fs.s09 = Arc(source=m.fs.C101.outlet, destination=m.fs.M101.vapor_recycle)
m.fs.s10a = Arc(source=m.fs.F101.liq_outlet, destination=m.fs.translator.inlet)
m.fs.s10b = Arc(source=m.fs.translator.outlet, destination=m.fs.H102.inlet)

# %% [markdown]
# We have now connected the unit model block using the arcs. However, each of these arcs link to ports on the two unit models that are connected. In this case, the ports consist of the state variables that need to be linked between the unit models. Pyomo provides a convenient method to write these equality constraints for us between two ports and this is done as follows:

# %%
TransformationFactory("network.expand_arcs").apply_to(m)

# %% [markdown]
# ### Appending additional constraints to the model
#
# Now, we will see how we can add additional constraints to the model using `Constraint` from Pyomo.
#
# Consider the reactor R101. By default, the conversion of a component is not calculated when we simulate the flowsheet. If we are interested either in specifying or constraining the conversion value, we can add the following constraint to calculate the conversion:
# $$ \text{Conversion of toluene} = \frac{\text{molar flow of toluene in the inlet} - \text{molar flow of toluene in the outlet}}{\text{molar flow of toluene in the inlet}} $$
#
# We add the constraint to the model as shown below.

# %%
# Define the conversion variables using 'Var'
m.fs.R101.conversion = Var(initialize=0.75, bounds=(0, 1))

# Append the constraint to the model
m.fs.R101.conv_constraint = Constraint(
    expr=m.fs.R101.conversion * m.fs.R101.inlet.flow_mol_phase_comp[0, "Vap", "toluene"]
    == (
        m.fs.R101.inlet.flow_mol_phase_comp[0, "Vap", "toluene"]
        - m.fs.R101.outlet.flow_mol_phase_comp[0, "Vap", "toluene"]
    )
)

# %% [markdown]
# ## Fixing feed conditions and Initializing the flowsheet
#
# Let us first check how many degrees of freedom exist for this flowsheet using the `degrees_of_freedom` tool we imported earlier.

# %%
print(degrees_of_freedom(m))
# Out:
# 29

# %%
# Check the degrees of freedom
assert degrees_of_freedom(m) == 29

# %% [markdown]
# We will now be fixing the toluene feed stream to the conditions shown in the flowsheet above. Please note that though this is a pure toluene feed, the remaining components are still assigned a very small non-zero value to help with convergence and initializing.

# %%
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Vap", "benzene"].fix(1e-5)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Vap", "toluene"].fix(1e-5)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Vap", "hydrogen"].fix(1e-5)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Vap", "methane"].fix(1e-5)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Liq", "benzene"].fix(1e-5)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Liq", "toluene"].fix(0.30)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Liq", "hydrogen"].fix(1e-5)
m.fs.M101.toluene_feed.flow_mol_phase_comp[0, "Liq", "methane"].fix(1e-5)
m.fs.M101.toluene_feed.temperature.fix(303.2)
m.fs.M101.toluene_feed.pressure.fix(350000)

# %% [markdown]
# Similarly, let us fix the hydrogen feed to the following conditions in the next cell:
#       <ul>
#          <li>F<sub>H2</sub> = 0.30 mol/s</li>
#          <li>F<sub>CH4</sub> = 0.02 mol/s</li>
#          <li>Remaining components = 1e-5 mol/s</li>
#          <li>T = 303.2 K</li>
#          <li>P = 350000 Pa</li>
#       </ul>

# %%
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Vap", "benzene"].fix(1e-5)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Vap", "toluene"].fix(1e-5)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Vap", "hydrogen"].fix(0.30)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Vap", "methane"].fix(0.02)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Liq", "benzene"].fix(1e-5)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Liq", "toluene"].fix(1e-5)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Liq", "hydrogen"].fix(1e-5)
m.fs.M101.hydrogen_feed.flow_mol_phase_comp[0, "Liq", "methane"].fix(1e-5)
m.fs.M101.hydrogen_feed.temperature.fix(303.2)
m.fs.M101.hydrogen_feed.pressure.fix(350000)

# %% [markdown]
# ### Fixing unit model specifications
#
# Now that we have fixed our inlet feed conditions, we will now be fixing the operating conditions for the unit models in the flowsheet. Let us set the H101 outlet temperature to 600 K.

# %%
# Fix the temperature of the outlet from the heater H101
m.fs.H101.outlet.temperature.fix(600)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Set the conditions for the reactor R101 to the following conditions:
#       <ul>
#          <li>`conversion` = 0.75 </li>
#          <li>`heat_duty` = 0</li>
#       </ul>
#
# Use Shift+Enter to run the cell once you have typed in your code.
# </div>

# %%
# Todo: Fix the 'conversion' of the reactor R101
m.fs.R101.conversion.fix(0.75)

# Todo: Fix the 'heat_duty' of the reactor R101
m.fs.R101.heat_duty.fix(0)

# %% [markdown]
# The Flash conditions for F101 can be set as follows.

# %%
# Fix the temperature of the vapor outlet from F101
m.fs.F101.vap_outlet.temperature.fix(325.0)

# Fix the pressure drop in the flash F101
m.fs.F101.deltaP.fix(0)

# %% [markdown]
# Let us fix the split fraction of the purge stream from the splitter S101 and the outlet pressure from the compressor C101

# %%
# Fix the split fraction of the 'purge' stream from S101
m.fs.S101.split_fraction[0, "purge"].fix(0.2)

# Fix the pressure of the outlet from the compressor C101
m.fs.C101.outlet.pressure.fix(350000)

# %% [markdown]
# Finally, let us fix the temperature of the outlet from H102 and the pressure drop in H102 as the following

# %%
# Fix the temperature of the outlet from the heater H102
m.fs.H102.outlet.temperature.fix(375)

# Fix the pressure drop in the heater H102
m.fs.H102.deltaP.fix(-200000)

# %% [markdown]
# To avoid convergence issues associated with poorly scaled variables and/or constraints, we scale the variables and constraints corresponding to the heaters H101 and H102, flash F101 and the reactor R101. Scaling factors for the flow rates, temperature, pressure, etc. have been defined in the property package: `ideal_VLE.py` file. Here, we set scaling factors only for the heat duty of the heater, the reaction extent, heat duty and volume of the reactor.

# %%
# Set scaling factors for heat duty, reaction extent and volume
iscale.set_scaling_factor(m.fs.H101.control_volume.heat, 1e-2)
iscale.set_scaling_factor(m.fs.R101.control_volume.heat, 1e-2)
iscale.set_scaling_factor(m.fs.R101.control_volume.rate_reaction_extent, 1)
iscale.set_scaling_factor(m.fs.R101.control_volume.volume, 1)
iscale.set_scaling_factor(m.fs.F101.control_volume.heat, 1e-2)
iscale.set_scaling_factor(m.fs.H102.control_volume.heat, 1e-2)

# Set the scaling factors for the remaining variables and all constraints
iscale.calculate_scaling_factors(m.fs.H101)
iscale.calculate_scaling_factors(m.fs.R101)
iscale.calculate_scaling_factors(m.fs.F101)
iscale.calculate_scaling_factors(m.fs.H102)
# Out:
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].flow_mol_phase
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Liq,toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].enth_mol_phase_comp[Vap,toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].eq_comp[benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].eq_comp[toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Liq,benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Liq,toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Vap,benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].enth_mol_phase_comp[Vap,toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].material_flow_terms[Liq,benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].material_flow_terms[Vap,benzene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].material_flow_terms[Liq,toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].material_flow_terms[Vap,toluene]
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].enthalpy_flow_terms[Liq], enthalpy_flow_terms
# 2024-05-06 23:03:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.H102.control_volume.properties_in[0.0].enthalpy_flow_terms[Vap], enthalpy_flow_terms

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# We have now defined all the feed conditions and the inputs required for the unit models. The system should now have 0 degrees of freedom i.e. should be a square problem. Please check that the degrees of freedom is 0.
#
# Use Shift+Enter to run the cell once you have typed in your code.
# </div>

# %%
# Todo: Check the degrees of freedom
print(degrees_of_freedom(m))
# Out:
# 0

# %%
# Check the degrees of freedom
assert degrees_of_freedom(m) == 0

# %% [markdown]
# ### Initialization
#
# This subsection will demonstrate how to use the built-in sequential decomposition tool to initialize our flowsheet.
#
# Let us first create an object for the `SequentialDecomposition` and specify our options for this.

# %%
seq = SequentialDecomposition()
seq.options.select_tear_method = "heuristic"
seq.options.tear_method = "Wegstein"
seq.options.iterLim = 3

# Using the SD tool
G = seq.create_graph(m)
heuristic_tear_set = seq.tear_set_arcs(G, method="heuristic")
order = seq.calculation_order(G)

# %% [markdown]
# Which is the tear stream? Display tear set and order

# %%
for o in heuristic_tear_set:
    print(o.name)
# Out:
# fs.s03

# %% [markdown]
# What sequence did the SD tool determine to solve this flowsheet with the least number of tears?

# %%
for o in order:
    print(o[0].name)
# Out:
# fs.H101
# fs.R101
# fs.F101
# fs.S101
# fs.C101
# fs.M101

# %% [markdown]
# The SequentialDecomposition tool has determined that the tear stream is the mixer outlet (s03 in the Figure above). We will need to provide a reasonable guess for this.
#
# For the initial guess, we assume that the flowrate of the recycle stream (s09) is zero. Consequently, the flow rate of the stream s03 is simply the sum of the flowrates of the toluene feed and hydrogen feed streams. Further, since the temperature and the pressure of both the toluene and hydrogen feed streams are the same, we specify their values as the initial guess for the temperature and pressure of the stream s03.

# %%
tear_guesses = {
    "flow_mol_phase_comp": {
        (0, "Vap", "benzene"): 1e-5,
        (0, "Vap", "toluene"): 1e-5,
        (0, "Vap", "hydrogen"): 0.30,
        (0, "Vap", "methane"): 0.02,
        (0, "Liq", "benzene"): 1e-5,
        (0, "Liq", "toluene"): 0.30,
        (0, "Liq", "hydrogen"): 1e-5,
        (0, "Liq", "methane"): 1e-5,
    },
    "temperature": {0: 303},
    "pressure": {0: 350000},
}

# Pass the tear_guess to the SD tool
seq.set_guesses_for(m.fs.H101.inlet, tear_guesses)

# %% [markdown]
# Next, we need to tell the tool how to initialize a particular unit. We will be writing a python function which takes in a "unit" and calls the initialize method on that unit. For the initialization, we will import a Block Triangularization Initializer which decomposes the model into a set of subproblems. These subproblems are solved using a block triangularization transformation before applying a simple Newton or user-selected solver. Methods such as block triangularization often solve faster and yield more reliable behavior than heuristic methods, but sometime struggle to decompose models with strongly coupled equations (e.g. column models, systems with counter-current flow, vapor-liquid equilibrium).

# %%
from idaes.core.initialization.block_triangularization import BlockTriangularizationInitializer
initializer = BlockTriangularizationInitializer(constraint_tolerance=1e-4)
def function(unit):
    print(unit.name)
    if isinstance(unit, Heater):  # Heaters have their own initialization method
        unit.initialize(outlvl=idaeslog.DEBUG)
    else:
        status = initializer.initialize(unit, output_level=idaeslog.DEBUG)

# %% [markdown]
# We are now ready to initialize our flowsheet in a sequential mode. Note that we specifically set the iteration limit to be 3 as we are trying to use this tool only to get a good set of initial values such that IPOPT can then take over and solve this flowsheet for us.

# %%
seq.run(m, function)
# Out:
# fs.H101
# 2024-05-06 23:03:43 [INFO] idaes.init.fs.H101.control_volume.properties_in: Initialization Step 1 - Dew and bubble points calculation completed.
# 2024-05-06 23:03:43 [INFO] idaes.init.fs.H101.control_volume.properties_in: Initialization Step 2 - Equilibrium temperature  calculation completed.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: WARNING: model contains export suffix 'scaling_factor' that contains 10
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: WARNING: model contains export suffix 'scaling_factor' that contains 25 keys
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: that are not Var, Constraint, Objective, or the model.  Skipping.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: tol=1e-06
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: max_iter=200
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: ******************************************************************************
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:          For more information visit http://projects.coin-or.org/Ipopt
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This version of Ipopt was compiled from source code available at
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     for large-scale scientific computation.  All technical papers, sales and
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     publicity material resulting from use of the HSL codes within IPOPT must
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:     contain the following acknowledgement:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         HSL, a collection of Fortran codes for large-scale scientific
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         computation. See http://www.hsl.rl.ac.uk.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: ******************************************************************************
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of nonzeros in equality constraint Jacobian...:       18
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of nonzeros in inequality constraint Jacobian.:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of nonzeros in Lagrangian Hessian.............:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total number of variables............................:       10
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                      variables with only lower bounds:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                 variables with lower and upper bounds:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                      variables with only upper bounds:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total number of equality constraints.................:       10
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total number of inequality constraints...............:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         inequality constraints with only lower bounds:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:    inequality constraints with lower and upper bounds:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:         inequality constraints with only upper bounds:        0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:    0  0.0000000e+00 7.00e+08 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:    1  0.0000000e+00 1.94e-08 0.00e+00  -1.0 7.00e+05    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of Iterations....: 1
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:                                    (scaled)                 (unscaled)
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Constraint violation....:   1.9441358745098113e-09    1.9441358745098111e-08
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Overall NLP error.......:   1.9441358745098113e-09    1.9441358745098111e-08
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of objective function evaluations             = 2
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of objective gradient evaluations             = 2
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of equality constraint evaluations            = 2
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of inequality constraint evaluations          = 0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of equality constraint Jacobian evaluations   = 2
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of inequality constraint Jacobian evaluations = 0
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Number of Lagrangian Hessian evaluations             = 1
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total CPU secs in IPOPT (w/o function evaluations)   =      0.002
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: Total CPU secs in NLP function evaluations           =      0.000
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in:
# 2024-05-06 23:03:43 [DEBUG] idaes.solve.fs.H101.control_volume.properties_in: EXIT: Optimal Solution Found.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101.control_volume.properties_out: Initialization Step 1 - Dew and bubble points calculation completed.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101.control_volume.properties_out: Initialization Step 2 - Equilibrium temperature  calculation completed.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: WARNING: model contains export suffix 'scaling_factor' that contains 10
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: WARNING: model contains export suffix 'scaling_factor' that contains 25 keys
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: that are not Var, Constraint, Objective, or the model.  Skipping.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: tol=1e-06
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: max_iter=200
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: ******************************************************************************
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:          For more information visit http://projects.coin-or.org/Ipopt
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This version of Ipopt was compiled from source code available at
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     for large-scale scientific computation.  All technical papers, sales and
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     publicity material resulting from use of the HSL codes within IPOPT must
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:     contain the following acknowledgement:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         HSL, a collection of Fortran codes for large-scale scientific
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         computation. See http://www.hsl.rl.ac.uk.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: ******************************************************************************
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of nonzeros in equality constraint Jacobian...:       31
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of nonzeros in inequality constraint Jacobian.:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of nonzeros in Lagrangian Hessian.............:       11
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total number of variables............................:       17
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                      variables with only lower bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                 variables with lower and upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                      variables with only upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total number of equality constraints.................:       17
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total number of inequality constraints...............:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         inequality constraints with only lower bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    inequality constraints with lower and upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:         inequality constraints with only upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    0  0.0000000e+00 7.00e+08 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    1  0.0000000e+00 9.70e+02 0.00e+00  -1.0 7.69e+05    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    2  0.0000000e+00 6.38e+02 0.00e+00  -1.0 4.73e+06    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    3  0.0000000e+00 3.67e+02 0.00e+00  -1.0 2.00e+07    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    4  0.0000000e+00 1.67e+02 0.00e+00  -1.0 5.27e+07    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    5  0.0000000e+00 4.93e+01 0.00e+00  -1.0 7.34e+07    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    6  0.0000000e+00 5.77e+00 0.00e+00  -1.0 4.19e+07    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    7  0.0000000e+00 9.14e-02 0.00e+00  -1.0 6.27e+06    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    8  0.0000000e+00 2.34e-05 0.00e+00  -2.5 1.02e+05    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:    9  0.0000000e+00 1.45e-12 0.00e+00  -5.7 2.62e+01    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of Iterations....: 9
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:                                    (scaled)                 (unscaled)
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Constraint violation....:   1.4495071809506044e-12    1.4495071809506044e-12
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Overall NLP error.......:   1.4495071809506044e-12    1.4495071809506044e-12
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of objective function evaluations             = 10
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of objective gradient evaluations             = 10
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of equality constraint evaluations            = 10
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of inequality constraint evaluations          = 0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of equality constraint Jacobian evaluations   = 10
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of inequality constraint Jacobian evaluations = 0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Number of Lagrangian Hessian evaluations             = 9
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: Total CPU secs in NLP function evaluations           =      0.000
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101.control_volume.properties_out: EXIT: Optimal Solution Found.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101.control_volume.properties_out: State Released.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101.control_volume: Initialization Complete
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101: Initialization Step 1 Complete.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: WARNING: model contains export suffix 'scaling_factor' that contains 11
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: WARNING: model contains export suffix 'scaling_factor' that contains 50 keys
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: that are not Var, Constraint, Objective, or the model.  Skipping.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: tol=1e-06
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: max_iter=200
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: ******************************************************************************
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:          For more information visit http://projects.coin-or.org/Ipopt
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: This version of Ipopt was compiled from source code available at
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:     for large-scale scientific computation.  All technical papers, sales and
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:     publicity material resulting from use of the HSL codes within IPOPT must
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:     contain the following acknowledgement:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:         HSL, a collection of Fortran codes for large-scale scientific
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:         computation. See http://www.hsl.rl.ac.uk.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: ******************************************************************************
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of nonzeros in equality constraint Jacobian...:      124
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of nonzeros in inequality constraint Jacobian.:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of nonzeros in Lagrangian Hessian.............:      115
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Total number of variables............................:       41
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:                      variables with only lower bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:                 variables with lower and upper bounds:        9
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:                      variables with only upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Total number of equality constraints.................:       41
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Total number of inequality constraints...............:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:         inequality constraints with only lower bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    inequality constraints with lower and upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:         inequality constraints with only upper bounds:        0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    0  0.0000000e+00 1.44e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    1  0.0000000e+00 8.53e+04 1.03e+01  -1.0 3.65e+04    -  1.44e-01 5.96e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    2  0.0000000e+00 5.59e+04 4.56e+02  -1.0 1.46e+04    -  9.90e-01 3.84e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    3  0.0000000e+00 5.46e+04 2.28e+04  -1.0 9.01e+03    -  9.64e-01 2.49e-02h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    4  0.0000000e+00 5.45e+04 8.49e+07  -1.0 8.79e+03    -  9.90e-01 2.77e-04h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    5r 0.0000000e+00 5.45e+04 1.00e+03   1.1 0.00e+00    -  0.00e+00 3.46e-07R  4
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    6r 0.0000000e+00 4.32e+04 4.37e+04   1.1 1.34e+04    -  2.15e-01 5.33e-03f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    7r 0.0000000e+00 1.29e+04 9.88e+04   1.1 1.38e+04    -  2.56e-03 2.12e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    8r 0.0000000e+00 3.28e+03 1.31e+05   1.1 1.50e+03  -2.0 1.24e-02 2.47e-03f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:    9r 0.0000000e+00 3.23e+03 2.81e+06   1.1 1.58e+04    -  8.61e-01 1.48e-02f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   10r 0.0000000e+00 2.43e+03 4.29e+05   1.1 1.02e+04    -  9.97e-01 2.29e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   11r 0.0000000e+00 3.36e+02 1.20e+06   1.1 4.65e+02    -  1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   12r 0.0000000e+00 2.29e+02 1.95e+05   1.1 3.06e+02    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   13r 0.0000000e+00 1.42e+02 3.95e+04   1.1 2.17e+02    -  1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   14r 0.0000000e+00 1.62e+02 5.12e+02   1.1 3.77e+00    -  1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   15r 0.0000000e+00 5.69e+02 2.24e+04  -1.0 7.95e+02    -  9.81e-01 5.87e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   16r 0.0000000e+00 3.53e+02 2.12e+05  -1.0 2.73e+04    -  3.65e-01 6.11e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   17r 0.0000000e+00 4.42e+02 5.36e+04  -1.0 2.88e+03    -  4.79e-01 6.39e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   18r 0.0000000e+00 9.98e+02 2.65e+04  -1.0 8.38e+02    -  5.00e-01 8.54e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   19r 0.0000000e+00 1.83e+03 2.59e+05  -1.0 1.21e+03    -  3.19e-01 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   20r 0.0000000e+00 1.71e+03 4.23e+04  -1.0 1.42e+03    -  9.89e-01 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   21r 0.0000000e+00 1.14e+03 3.73e+03  -1.0 1.49e+03    -  6.29e-01 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   22r 0.0000000e+00 3.09e+02 3.76e+02  -1.0 5.77e+02    -  1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   23r 0.0000000e+00 1.41e+01 1.83e+01  -1.0 1.10e+02    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   24r 0.0000000e+00 3.90e-01 4.41e-02  -1.0 3.92e+00    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   25r 0.0000000e+00 1.40e-01 1.92e+03  -3.9 4.97e+02    -  9.59e-01 9.19e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   26r 0.0000000e+00 8.88e-02 1.41e+03  -3.9 2.13e+01  -2.5 9.86e-01 7.90e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   27r 0.0000000e+00 4.93e-01 5.24e+00  -3.9 6.41e+01  -3.0 1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   28r 0.0000000e+00 4.43e+00 5.37e-01  -3.9 1.92e+02  -3.4 1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   29r 0.0000000e+00 1.36e+01 1.81e+01  -3.9 5.76e+02  -3.9 1.00e+00 5.35e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   30r 0.0000000e+00 1.36e+01 2.85e+02  -3.9 1.22e+03  -4.4 1.00e+00 3.22e-05f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   31r 0.0000000e+00 2.16e+02 3.96e+02  -3.9 7.87e+02  -4.9 8.49e-01 7.82e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   32r 0.0000000e+00 7.63e+03 4.43e+02  -3.9 5.96e+05    -  5.23e-02 2.25e-02f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   33r 0.0000000e+00 7.63e+03 2.31e+03  -3.9 3.06e+05    -  5.19e-01 2.07e-05f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   34r 0.0000000e+00 7.46e+03 3.20e+04  -3.9 1.07e+05    -  1.00e+00 2.19e-02f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   35r 0.0000000e+00 4.51e+03 1.04e+04  -3.9 1.05e+05    -  1.00e+00 4.03e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   36r 0.0000000e+00 1.37e+03 7.02e+04  -3.9 3.41e+03    -  1.00e+00 7.08e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   37r 0.0000000e+00 1.25e+03 7.85e+04  -3.9 2.26e+03    -  3.92e-02 9.21e-02f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   38r 0.0000000e+00 7.28e+02 1.10e+05  -3.9 2.08e+03    -  4.11e-01 4.18e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   39r 0.0000000e+00 3.66e+01 5.99e+07  -3.9 1.29e+03    -  6.69e-01 9.98e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   40r 0.0000000e+00 3.66e+01 5.99e+07  -3.9 7.57e+04    -  4.51e-05 3.08e-05h  4
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   41r 0.0000000e+00 3.66e+01 5.98e+07  -3.9 9.69e+03    -  1.13e-02 1.63e-03h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   42r 0.0000000e+00 3.66e+01 5.98e+07  -3.9 8.70e-01   0.1 2.01e-01 8.32e-05h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   43r 0.0000000e+00 2.46e+01 4.95e+07  -3.9 4.27e+00    -  6.47e-02 5.90e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   44r 0.0000000e+00 2.28e+01 4.99e+07  -3.9 5.27e+02    -  4.58e-02 8.75e-02h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   45r 0.0000000e+00 2.26e+01 7.46e+07  -3.9 4.09e+00  -0.4 4.17e-02 7.91e-03h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   46r 0.0000000e+00 1.91e+01 4.74e+07  -3.9 1.38e+00  -0.9 5.88e-01 1.65e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   47r 0.0000000e+00 1.91e+01 4.41e+07  -3.9 2.21e+02    -  1.35e-02 1.07e-03h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   48r 0.0000000e+00 1.71e+01 3.71e+07  -3.9 5.55e+00  -1.4 3.54e-02 1.46e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   49r 0.0000000e+00 1.71e+01 3.32e+07  -3.9 3.21e+00  -0.9 4.30e-02 4.75e-04f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   50r 0.0000000e+00 1.52e+01 2.01e+07  -3.9 6.63e+00  -1.4 1.22e-02 3.39e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   51r 0.0000000e+00 1.51e+01 2.00e+07  -3.9 6.02e-01  -1.0 1.00e+00 7.26e-03f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   52r 0.0000000e+00 1.12e+01 1.12e+08  -3.9 4.72e+00  -1.5 1.50e-01 9.33e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   53r 0.0000000e+00 1.56e+00 1.55e+07  -3.9 1.23e-01  -0.1 1.00e+00 8.51e-01f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   54r 0.0000000e+00 7.15e-03 7.50e+04  -3.9 4.29e-02  -0.6 1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   55r 0.0000000e+00 3.72e-03 9.28e+02  -3.9 1.18e-01  -1.1 1.00e+00 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   56r 0.0000000e+00 1.18e+01 4.34e+05  -3.9 1.34e+04    -  1.40e-01 9.60e-04f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   57r 0.0000000e+00 1.67e+01 8.31e+05  -3.9 1.06e+04    -  6.17e-01 9.58e-02f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   58r 0.0000000e+00 2.61e+01 2.16e+06  -3.9 1.14e+03    -  5.94e-01 6.82e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   59r 0.0000000e+00 9.17e+00 7.65e+05  -3.9 7.52e+01    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   60r 0.0000000e+00 6.11e+00 5.10e+05  -3.9 5.58e+02    -  1.00e+00 3.13e-01h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   61r 0.0000000e+00 2.76e+00 2.29e+05  -3.9 3.58e+01    -  7.38e-01 1.00e+00f  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   62r 0.0000000e+00 1.03e+00 8.65e+04  -3.9 2.11e+01    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   63r 0.0000000e+00 2.89e-02 2.42e+03  -3.9 1.60e+00    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:   64r 0.0000000e+00 8.82e-05 4.53e+00  -3.9 1.01e-01    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of Iterations....: 64
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:                                    (scaled)                 (unscaled)
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Constraint violation....:   2.1745645950588255e-07    8.8165921624749899e-05
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Overall NLP error.......:   2.1745645950588255e-07    8.8165921624749899e-05
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of objective function evaluations             = 73
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of objective gradient evaluations             = 7
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of equality constraint evaluations            = 73
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of inequality constraint evaluations          = 0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of equality constraint Jacobian evaluations   = 66
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of inequality constraint Jacobian evaluations = 0
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Number of Lagrangian Hessian evaluations             = 64
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Total CPU secs in IPOPT (w/o function evaluations)   =      0.054
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: Total CPU secs in NLP function evaluations           =      0.002
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101:
# 2024-05-06 23:03:45 [DEBUG] idaes.solve.fs.H101: EXIT: Optimal Solution Found.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101.control_volume.properties_in: State Released.
# 2024-05-06 23:03:45 [INFO] idaes.init.fs.H101: Initialization Complete: optimal - Optimal Solution Found
# fs.R101
# fs.F101
# fs.S101
# fs.translator
# fs.C101
# fs.H102
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: WARNING: model contains export suffix 'scaling_factor' that contains 9
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: tol=1e-06
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: max_iter=200
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: ******************************************************************************
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:          For more information visit http://projects.coin-or.org/Ipopt
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: This version of Ipopt was compiled from source code available at
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:     for large-scale scientific computation.  All technical papers, sales and
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:     publicity material resulting from use of the HSL codes within IPOPT must
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:     contain the following acknowledgement:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:         HSL, a collection of Fortran codes for large-scale scientific
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:         computation. See http://www.hsl.rl.ac.uk.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: ******************************************************************************
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of nonzeros in equality constraint Jacobian...:       19
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of nonzeros in inequality constraint Jacobian.:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of nonzeros in Lagrangian Hessian.............:        9
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Total number of variables............................:       14
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:                      variables with only lower bounds:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:                 variables with lower and upper bounds:        4
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:                      variables with only upper bounds:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Total number of equality constraints.................:       11
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Total number of inequality constraints...............:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:         inequality constraints with only lower bounds:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    inequality constraints with lower and upper bounds:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:         inequality constraints with only upper bounds:        0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    0  0.0000000e+00 8.52e+04 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Warning: Cutting back alpha due to evaluation error
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Warning: Cutting back alpha due to evaluation error
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    1  0.0000000e+00 7.46e+04 0.00e+00  -1.0 2.37e+05    -  1.00e+00 1.25e-01h  4
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Warning: Cutting back alpha due to evaluation error
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    2  0.0000000e+00 3.73e+04 0.00e+00  -1.0 1.42e+05    -  1.00e+00 5.00e-01h  2
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    3  0.0000000e+00 4.67e+02 0.00e+00  -1.0 3.73e+04    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    4  0.0000000e+00 2.33e+00 0.00e+00  -1.0 4.30e+04    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    5  0.0000000e+00 5.31e-01 0.00e+00  -1.0 8.55e+04    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    6  0.0000000e+00 3.21e-01 0.00e+00  -1.7 1.30e+05    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    7  0.0000000e+00 1.29e-01 0.00e+00  -1.7 1.14e+05    -  1.00e+00 1.00e+00H  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    8  0.0000000e+00 2.12e-04 0.00e+00  -2.5 1.17e+04    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:    9  0.0000000e+00 3.11e-08 0.00e+00  -3.8 1.20e+02    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:   10  0.0000000e+00 1.46e-11 0.00e+00  -5.7 1.76e-02    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:   11  0.0000000e+00 1.46e-11 0.00e+00  -7.0 1.68e-10    -  1.00e+00 1.00e+00   0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of Iterations....: 11
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:                                    (scaled)                 (unscaled)
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Constraint violation....:   1.4551915228366852e-11    1.4551915228366852e-11
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Complementarity.........:   9.0909090909090729e-08    9.0909090909090729e-08
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Overall NLP error.......:   9.0909090909090729e-08    9.0909090909090729e-08
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of objective function evaluations             = 14
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of objective gradient evaluations             = 12
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of equality constraint evaluations            = 17
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of inequality constraint evaluations          = 0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of equality constraint Jacobian evaluations   = 12
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of inequality constraint Jacobian evaluations = 0
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Number of Lagrangian Hessian evaluations             = 11
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Total CPU secs in NLP function evaluations           =      0.000
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in:
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: EXIT: Optimal Solution Found.
# 2024-05-06 23:03:46 [INFO] idaes.init.fs.H102.control_volume.properties_in: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: WARNING: model contains export suffix 'scaling_factor' that contains 7
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:46 [DEBUG] idaes.solve.fs.H102.control_volume.properties_in: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# ...
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: WARNING: model contains export suffix 'scaling_factor' that contains 5
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: tol=1e-06
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: max_iter=200
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: ******************************************************************************
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:          For more information visit http://projects.coin-or.org/Ipopt
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: This version of Ipopt was compiled from source code available at
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:     for large-scale scientific computation.  All technical papers, sales and
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:     publicity material resulting from use of the HSL codes within IPOPT must
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:     contain the following acknowledgement:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:         HSL, a collection of Fortran codes for large-scale scientific
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:         computation. See http://www.hsl.rl.ac.uk.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: ******************************************************************************
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of nonzeros in equality constraint Jacobian...:       45
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of nonzeros in inequality constraint Jacobian.:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of nonzeros in Lagrangian Hessian.............:       21
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Total number of variables............................:       18
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:                      variables with only lower bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:                 variables with lower and upper bounds:        4
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:                      variables with only upper bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Total number of equality constraints.................:       18
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Total number of inequality constraints...............:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:         inequality constraints with only lower bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:    inequality constraints with lower and upper bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:         inequality constraints with only upper bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:    0  0.0000000e+00 9.56e-05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:    1  0.0000000e+00 1.82e-12 6.26e-08  -1.7 1.69e-01    -  1.00e+00 1.00e+00h  1
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of Iterations....: 1
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:                                    (scaled)                 (unscaled)
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Constraint violation....:   4.3993410432641362e-13    1.8189894035458565e-12
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Overall NLP error.......:   4.3993410432641362e-13    1.8189894035458565e-12
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of objective function evaluations             = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of objective gradient evaluations             = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of equality constraint evaluations            = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of inequality constraint evaluations          = 0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of equality constraint Jacobian evaluations   = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of inequality constraint Jacobian evaluations = 0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Number of Lagrangian Hessian evaluations             = 1
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: Total CPU secs in NLP function evaluations           =      0.000
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102.control_volume.properties_out: EXIT: Optimal Solution Found.
# 2024-05-06 23:03:56 [INFO] idaes.init.fs.H102.control_volume.properties_out: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:03:56 [INFO] idaes.init.fs.H102.control_volume.properties_out: State Released.
# 2024-05-06 23:03:56 [INFO] idaes.init.fs.H102.control_volume: Initialization Complete
# 2024-05-06 23:03:56 [INFO] idaes.init.fs.H102: Initialization Step 1 Complete.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: WARNING: model contains export suffix 'scaling_factor' that contains 7
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: component keys that are not exported as part of the NL file.  Skipping.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Ipopt 3.13.2: nlp_scaling_method=gradient-based
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: tol=1e-06
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: max_iter=200
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: ******************************************************************************
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:  Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:          For more information visit http://projects.coin-or.org/Ipopt
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: This version of Ipopt was compiled from source code available at
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:     for large-scale scientific computation.  All technical papers, sales and
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:     publicity material resulting from use of the HSL codes within IPOPT must
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:     contain the following acknowledgement:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:         HSL, a collection of Fortran codes for large-scale scientific
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:         computation. See http://www.hsl.rl.ac.uk.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: ******************************************************************************
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of nonzeros in equality constraint Jacobian...:      131
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of nonzeros in inequality constraint Jacobian.:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of nonzeros in Lagrangian Hessian.............:       70
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Total number of variables............................:       41
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:                      variables with only lower bounds:        2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:                 variables with lower and upper bounds:       10
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:                      variables with only upper bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Total number of equality constraints.................:       41
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Total number of inequality constraints...............:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:         inequality constraints with only lower bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:    inequality constraints with lower and upper bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:         inequality constraints with only upper bounds:        0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:    0  0.0000000e+00 2.00e-06 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:    1  0.0000000e+00 3.67e-08 1.00e-02  -1.0 1.69e-01    -  9.90e-01 1.00e+00h  1
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of Iterations....: 1
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:                                    (scaled)                 (unscaled)
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Constraint violation....:   2.0643037116205669e-10    3.6730853025801480e-08
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Overall NLP error.......:   2.0643037116205669e-10    3.6730853025801480e-08
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of objective function evaluations             = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of objective gradient evaluations             = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of equality constraint evaluations            = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of inequality constraint evaluations          = 0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of equality constraint Jacobian evaluations   = 2
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of inequality constraint Jacobian evaluations = 0
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Number of Lagrangian Hessian evaluations             = 1
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: Total CPU secs in NLP function evaluations           =      0.000
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102:
# 2024-05-06 23:03:56 [DEBUG] idaes.solve.fs.H102: EXIT: Optimal Solution Found.
# 2024-05-06 23:03:56 [INFO] idaes.init.fs.H102: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:03:57 [INFO] idaes.init.fs.H102.control_volume.properties_in: State Released.
# 2024-05-06 23:03:57 [INFO] idaes.init.fs.H102: Initialization Complete: optimal - Optimal Solution Found

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# We have now initialized the flowsheet. Let us run the flowsheet in a simulation mode to look at the results.
# </div>

# %%
# Create the solver object
solver = get_solver()

# Solve the model
results = solver.solve(m, tee=True)
# Out:
# WARNING: model contains export suffix 'scaling_factor' that contains 6
# component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'scaling_factor' that contains 150 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# Ipopt 3.13.2: nlp_scaling_method=gradient-based
# tol=1e-06
# max_iter=200
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1101
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      884
#
# Total number of variables............................:      363
#                      variables with only lower bounds:        8
#                 variables with lower and upper bounds:      155
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      363
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.82e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 8.69e+03 1.44e+03  -1.0 2.00e+04    -  9.71e-01 4.67e-01H  1
#    2  0.0000000e+00 1.29e+03 1.56e+03  -1.0 1.60e+04    -  9.79e-01 4.90e-01h  1
#    3  0.0000000e+00 1.18e+03 1.55e+05  -1.0 1.40e+04    -  9.90e-01 4.99e-01h  1
#    4  0.0000000e+00 5.46e+02 2.32e+09  -1.0 8.43e+03    -  1.00e+00 9.82e-01h  1
#    5  0.0000000e+00 5.46e+03 3.66e+10  -1.0 5.97e+02    -  1.00e+00 9.90e-01h  1
#    6  0.0000000e+00 1.21e+03 8.01e+09  -1.0 5.75e+00    -  1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 6.41e+00 3.87e+07  -1.0 1.53e-03    -  1.00e+00 1.00e+00f  1
#    8  0.0000000e+00 1.96e-04 9.35e+02  -1.0 7.29e-06    -  1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 3.73e-08 4.94e-02  -3.8 3.45e-08    -  1.00e+00 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.5042487559854813e+04    1.5042487559854813e+04
# Constraint violation....:   2.9103830456733704e-11    3.7252902984619141e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.9103830456733704e-11    1.5042487559854813e+04
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.033
# Total CPU secs in NLP function evaluations           =      0.004
#
# EXIT: Optimal Solution Found.

# %%
# Check solver solve status
from pyomo.environ import TerminationCondition

assert results.solver.termination_condition == TerminationCondition.optimal

# %% [markdown]
# ### Add distillation column
#
# As mentioned earlier, the `SequentialDecomposition` tool currently does not support the distillation column model. Thus, we have not included the distillation column in the flowsheet. Now that we have a converged flowsheet, we will add the distillation column and simulate the entire flowsheet.
#
# In the following, we will
# - Add the distillation column
# - Connect it to the heater
# - Add the necessary equality constraints
# - Propogate the state variable information from the outlet of the heater to the inlet of the distillation column
# - Fix the degrees of freedom of the distillation block (reflux ratio, boilup ratio, and condenser pressure)
# - Scale the control volume heat variables to help convergence
# - Initialize the distillation block.

# %%
# Add distillation column to the flowsheet
m.fs.D101 = TrayColumn(
    number_of_trays=10,
    feed_tray_location=5,
    condenser_type=CondenserType.totalCondenser,
    condenser_temperature_spec=TemperatureSpec.atBubblePoint,
    property_package=m.fs.BT_params,
)

# Connect the outlet from the heater H102 to the distillation column
m.fs.s11 = Arc(source=m.fs.H102.outlet, destination=m.fs.D101.feed)

# Add the necessary equality constraints
TransformationFactory("network.expand_arcs").apply_to(m)

# Propagate the state
propagate_state(m.fs.s11)

# Fix the reflux ratio, boilup ratio, and the condenser pressure
m.fs.D101.condenser.reflux_ratio.fix(0.5)
m.fs.D101.reboiler.boilup_ratio.fix(0.5)
m.fs.D101.condenser.condenser_pressure.fix(150000)

# set scaling factors
# Set scaling factors for heat duty
iscale.set_scaling_factor(m.fs.D101.condenser.control_volume.heat, 1e-2)
iscale.set_scaling_factor(m.fs.D101.reboiler.control_volume.heat, 1e-2)

# Set the scaling factors for the remaining variables and all constraints
iscale.calculate_scaling_factors(m.fs.D101)

# Initialize the distillation column
m.fs.D101.initialize(outlvl=idaeslog.INFO)
# Out:
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_feed[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_liq[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_in_vap[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].material_flow_terms[Liq,benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].material_flow_terms[Vap,benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].material_flow_terms[Liq,toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].material_flow_terms[Vap,toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].enthalpy_flow_terms[Liq], enthalpy_flow_terms
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.properties_in[0.0].enthalpy_flow_terms[Vap], enthalpy_flow_terms
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].flow_mol_phase
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].eq_comp[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].eq_comp[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].eq_phase_equilibrium[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].eq_phase_equilibrium[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].eq_P_vap[benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_out[0.0].eq_P_vap[toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].material_flow_terms[Liq,benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].material_flow_terms[Vap,benzene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].material_flow_terms[Liq,toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].material_flow_terms[Vap,toluene]
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].enthalpy_flow_terms[Liq], enthalpy_flow_terms
# 2024-05-06 23:03:58 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.reboiler.control_volume.properties_in[0.0].enthalpy_flow_terms[Vap], enthalpy_flow_terms
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[2].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[3].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[7].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[8].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[9].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[10].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[4].e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.e_flow_liq_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.e_mole_frac_liq_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.e_mole_frac_liq_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.stripping_section[6].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.feed_tray.e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].e_flow_vap_out[0.0]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].e_mole_frac_vap_out[0.0,benzene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.rectification_section[1].e_mole_frac_vap_out[0.0,toluene]
# 2024-05-06 23:03:59 [WARNING] idaes.core.util.scaling: Missing scaling factor for fs.D101.condenser.control_volume.e_flow_reflux[0.0]
# ...
# 2024-05-06 23:04:13 [INFO] idaes.init.fs.D101.stripping_section[6].properties_in_vap: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:13 [INFO] idaes.init.fs.D101.stripping_section[6].properties_in_vap: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:13 [INFO] idaes.init.fs.D101.stripping_section[6].properties_in_vap: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:13 [INFO] idaes.init.fs.D101.stripping_section[6].properties_in_vap: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:13 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: State Released.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_out: Initialization Complete: optimal - Optimal Solution Found
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6]: Mass balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6]: Mass and energy balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6]: Mass, energy and pressure balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6]: Initialization complete, status optimal - Optimal Solution Found.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[6].properties_in_vap: State Released.
# 2024-05-06 23:04:14 [INFO] idaes.init.fs.D101.stripping_section[7]: Begin initialization.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_liq: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_liq: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_liq: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_liq: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_liq: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_vap: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_vap: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_vap: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_vap: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:15 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_vap: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: State Released.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_out: Initialization Complete: optimal - Optimal Solution Found
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7]: Mass balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7]: Mass and energy balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7]: Mass, energy and pressure balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7]: Initialization complete, status optimal - Optimal Solution Found.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_vap: State Released.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[7].properties_in_liq: State Released.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[8]: Begin initialization.
# 2024-05-06 23:04:16 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_liq: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_liq: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_liq: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_liq: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_liq: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_vap: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_vap: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_vap: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_vap: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_vap: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:17 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: State Released.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_out: Initialization Complete: optimal - Optimal Solution Found
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8]: Mass balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8]: Mass and energy balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8]: Mass, energy and pressure balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8]: Initialization complete, status optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_vap: State Released.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[8].properties_in_liq: State Released.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[9]: Begin initialization.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_liq: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:18 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_liq: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_liq: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_liq: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_liq: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_vap: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_vap: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_vap: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_vap: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:19 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_vap: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: State Released.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_out: Initialization Complete: optimal - Optimal Solution Found
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9]: Mass balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9]: Mass and energy balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9]: Mass, energy and pressure balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9]: Initialization complete, status optimal - Optimal Solution Found.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_vap: State Released.
# 2024-05-06 23:04:20 [INFO] idaes.init.fs.D101.stripping_section[9].properties_in_liq: State Released.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10]: Begin initialization.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_liq: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_liq: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_liq: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_liq: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_liq: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_vap: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_vap: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:21 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_vap: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_vap: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_vap: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: Initialization Step 1 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: Initialization Step 2 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: Initialization Step 3 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: Initialization Step 4 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: Initialization Step 5 optimal - Optimal Solution Found.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: State Released.
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10].properties_out: Initialization Complete: optimal - Optimal Solution Found
# 2024-05-06 23:04:22 [INFO] idaes.init.fs.D101.stripping_section[10]: Mass balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101.stripping_section[10]: Mass and energy balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101.stripping_section[10]: Mass, energy and pressure balance solve optimal - Optimal Solution Found.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101.stripping_section[10]: Initialization complete, status optimal - Optimal Solution Found.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_liq: State Released.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101: Rectification section initialization status optimal - Optimal Solution Found.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101: Stripping section initialization status optimal - Optimal Solution Found.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101.rectification_section[4].properties_in_vap: State Released.
# 2024-05-06 23:04:23 [INFO] idaes.init.fs.D101.stripping_section[6].properties_in_liq: State Released.
# 2024-05-06 23:04:24 [INFO] idaes.init.fs.D101: Column section initialization status optimal - Optimal Solution Found.
# 2024-05-06 23:04:24 [INFO] idaes.init.fs.D101.rectification_section[1].properties_in_liq: State Released.
# 2024-05-06 23:04:24 [INFO] idaes.init.fs.D101: Column section + Condenser initialization status optimal - Optimal Solution Found.
# 2024-05-06 23:04:24 [INFO] idaes.init.fs.D101.stripping_section[10].properties_in_vap: State Released.
# 2024-05-06 23:04:24 [INFO] idaes.init.fs.D101: Column section + Condenser + Reboiler initialization status optimal - Optimal Solution Found.
# 2024-05-06 23:04:24 [INFO] idaes.init.fs.D101.feed_tray.properties_in_feed: State Released.

# %% [markdown]
# ## Adding expressions to compute capital and operating costs
#
# In this section, we will add a few Expressions that allow us to evaluate the performance. Expressions provide a convenient way of calculating certain values that are a function of the variables defined in the model. For more details on Expressions, please refer to: https://pyomo.readthedocs.io/en/stable/pyomo_modeling_components/Expressions.html

# %%
# Expression to compute the total cooling cost
m.fs.cooling_cost = Expression(
    expr=0.25e-7 * (-m.fs.F101.heat_duty[0])
    + 0.2e-7 * (-m.fs.D101.condenser.heat_duty[0])
)

# Expression to compute the total heating cost
m.fs.heating_cost = Expression(
    expr=2.2e-7 * m.fs.H101.heat_duty[0]
    + 1.2e-7 * m.fs.H102.heat_duty[0]
    + 1.9e-7 * m.fs.D101.reboiler.heat_duty[0]
)

# Expression to compute the total operating cost
m.fs.operating_cost = Expression(
    expr=(3600 * 24 * 365 * (m.fs.heating_cost + m.fs.cooling_cost))
)

# Expression to compute the total capital cost
m.fs.capital_cost = Expression(expr=1e5 * m.fs.R101.volume[0])

# %% [markdown]
# ### Solve the entire flowsheet

# %%
# Check that the degrees of freedom is zero
assert degrees_of_freedom(m) == 0

# %%
solver.solve(m, tee=True)
# Out:
# WARNING: model contains export suffix 'scaling_factor' that contains 7
# component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'scaling_factor' that contains 150 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# Ipopt 3.13.2: nlp_scaling_method=gradient-based
# tol=1e-06
# max_iter=200
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     4046
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2383
#
# Total number of variables............................:     1169
#                      variables with only lower bounds:      112
#                 variables with lower and upper bounds:      365
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1169
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.83e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 8.70e+03 1.49e+03  -1.0 3.69e+04    -  9.71e-01 4.62e-01H  1
#    2  0.0000000e+00 1.53e+03 1.56e+03  -1.0 6.75e+03    -  9.77e-01 4.89e-01h  1
#    3  0.0000000e+00 1.37e+03 1.55e+05  -1.0 9.37e+03    -  9.90e-01 4.99e-01h  1
#    4  0.0000000e+00 6.14e+02 2.31e+09  -1.0 6.09e+03    -  1.00e+00 9.81e-01h  1
#    5  0.0000000e+00 5.32e+03 3.62e+10  -1.0 5.56e+02    -  1.00e+00 9.90e-01h  1
#    6  0.0000000e+00 1.16e+03 7.80e+09  -1.0 5.36e+00    -  1.00e+00 1.00e+00h  1
#    7  0.0000000e+00 5.96e+00 3.64e+07  -1.0 1.47e-03    -  1.00e+00 1.00e+00f  1
#    8  0.0000000e+00 1.69e-04 8.14e+02  -1.0 6.78e-06    -  1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 1.49e-08 7.32e-02  -3.8 1.98e-07    -  1.00e+00 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.5042556664487987e+04    1.5042556664487987e+04
# Constraint violation....:   2.9103830456733704e-11    1.4901161193847656e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.9103830456733704e-11    1.5042556664487987e+04
#
#
# Number of objective function evaluations             = 11
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 11
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.100
# Total CPU secs in NLP function evaluations           =      0.018
#
# EXIT: Optimal Solution Found.
# {'Problem': [{'Lower bound': -inf, 'Upper bound': inf, 'Number of objectives': 1, 'Number of constraints': 1169, 'Number of variables': 1169, 'Sense': 'unknown'}], 'Solver': [{'Status': 'ok', 'Message': 'Ipopt 3.13.2\\x3a Optimal Solution Found', 'Termination condition': 'optimal', 'Id': 0, 'Error rc': 0, 'Time': 0.1980137825012207}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
# Check solver solve status
from pyomo.environ import TerminationCondition

assert results.solver.termination_condition == TerminationCondition.optimal

# %% [markdown]
# ## Analyze the Results of the Square Problem
#
# How much is the total cost (operating cost + capital cost), operating cost, capital cost, benzene purity in the distillate from the distilation column, and conversion of toluene in the reactor?

# %%
print("total cost = $", value(m.fs.capital_cost) + value(m.fs.operating_cost))
print("operating cost = $", value(m.fs.operating_cost))
print("capital cost = $", value(m.fs.capital_cost))
print()
print(
    "Distillate flowrate = ",
    value(m.fs.D101.condenser.distillate.flow_mol[0]()),
    "mol/s",
)
print(
    "Benzene purity = ",
    100 * value(m.fs.D101.condenser.distillate.mole_frac_comp[0, "benzene"]),
    "%",
)
print("Residue flowrate = ", value(m.fs.D101.reboiler.bottoms.flow_mol[0]()), "mol/s")
print(
    "Toluene purity = ",
    100 * value(m.fs.D101.reboiler.bottoms.mole_frac_comp[0, "toluene"]),
    "%",
)
print()
print("Conversion = ", 100 * value(m.fs.R101.conversion), "%")
print()
print(
    "Overhead benzene loss in F101 = ",
    100
    * value(m.fs.F101.vap_outlet.flow_mol_phase_comp[0, "Vap", "benzene"])
    / value(m.fs.R101.outlet.flow_mol_phase_comp[0, "Vap", "benzene"]),
    "%",
)
# Out:
# total cost = $ 442300.43702229083
# operating cost = $ 427595.6968378232
# capital cost = $ 14704.740184467655
#
# Distillate flowrate =  0.16196866526835388 mol/s
# Benzene purity =  89.49161665800823 %
# Residue flowrate =  0.10514986090683802 mol/s
# Toluene purity =  43.32260291055218 %
#
# Conversion =  75.0 %
#
# Overhead benzene loss in F101 =  42.16193848360323 %

# %%
import pytest

print(value(m.fs.operating_cost))
assert value(m.fs.operating_cost) == pytest.approx(427596.731, abs=100)
print(value(m.fs.capital_cost))
assert value(m.fs.capital_cost) == pytest.approx(14704.740, abs=100)
# Out:
# 427595.6968378232
# 14704.740184467655

# %% [markdown]
# Get the state of the streams entering and leaving the reactor R101

# %%
m.fs.R101.report()
# Out:
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value   : Units      : Fixed : Bounds
#     Heat Duty :  0.0000 :       watt :  True : (None, None)
#        Volume : 0.14705 : meter ** 3 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet     Outlet
#     flow_mol_phase_comp ('Liq', 'benzene')   mole / second 1.2993e-07 1.2993e-07
#     flow_mol_phase_comp ('Liq', 'toluene')   mole / second 8.4147e-07 8.4147e-07
#     flow_mol_phase_comp ('Liq', 'methane')   mole / second 1.0000e-12 1.0000e-12
#     flow_mol_phase_comp ('Liq', 'hydrogen')  mole / second 1.0000e-12 1.0000e-12
#     flow_mol_phase_comp ('Vap', 'benzene')   mole / second    0.11936    0.35374
#     flow_mol_phase_comp ('Vap', 'toluene')   mole / second    0.31252   0.078129
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second     1.0377     1.2721
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second    0.56260    0.32821
#     temperature                                     kelvin     600.00     771.85
#     pressure                                        pascal 3.5000e+05 3.5000e+05
# ====================================================================================

# %% [markdown]
# Get the state of the streams entering and leaving the reactor R101

# %%
m.fs.F101.report()
# Out:
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty : -70343. :   watt : False : (None, None)
#     Pressure Change :  0.0000 : pascal :  True : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     flow_mol_phase_comp ('Liq', 'benzene')   mole / second 1.2993e-07   1.0000e-08       0.20460
#     flow_mol_phase_comp ('Liq', 'toluene')   mole / second 8.4147e-07   1.0000e-08      0.062520
#     flow_mol_phase_comp ('Liq', 'methane')   mole / second 1.0000e-12   1.0000e-08    2.6712e-07
#     flow_mol_phase_comp ('Liq', 'hydrogen')  mole / second 1.0000e-12   1.0000e-08    2.6712e-07
#     flow_mol_phase_comp ('Vap', 'benzene')   mole / second    0.35374      0.14915    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'toluene')   mole / second   0.078129     0.015610    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second     1.2721       1.2721    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second    0.32821      0.32821    1.0000e-08
#     temperature                                     kelvin     771.85       325.00        325.00
#     pressure                                        pascal 3.5000e+05   3.5000e+05    3.5000e+05
# ====================================================================================

# %% [markdown]
# Next, let's look at how much benzene we are losing with the light gases out of F101. IDAES has tools for creating stream tables based on the `Arcs` and/or `Ports` in a flowsheet. Let us create and print a simple stream table showing the stream leaving the reactor and the vapor stream from F101.
#
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# How much benzene are we losing in the F101 vapor outlet stream?
# </div>

# %%
from idaes.core.util.tables import (
    create_stream_table_dataframe,
    stream_table_dataframe_to_string,
)

st = create_stream_table_dataframe({"Reactor": m.fs.s05, "Light Gases": m.fs.s06})
print(stream_table_dataframe_to_string(st))
# Out:
#                                             Units        Reactor   Light Gases
# flow_mol_phase_comp ('Liq', 'benzene')   mole / second 1.2993e-07  1.0000e-08
# flow_mol_phase_comp ('Liq', 'toluene')   mole / second 8.4147e-07  1.0000e-08
# flow_mol_phase_comp ('Liq', 'methane')   mole / second 1.0000e-12  1.0000e-08
# flow_mol_phase_comp ('Liq', 'hydrogen')  mole / second 1.0000e-12  1.0000e-08
# flow_mol_phase_comp ('Vap', 'benzene')   mole / second    0.35374     0.14915
# flow_mol_phase_comp ('Vap', 'toluene')   mole / second   0.078129    0.015610
# flow_mol_phase_comp ('Vap', 'methane')   mole / second     1.2721      1.2721
# flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second    0.32821     0.32821
# temperature                                     kelvin     771.85      325.00
# pressure                                        pascal 3.5000e+05  3.5000e+05

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# You can querry additional variables here if you like.
#
# Use Shift+Enter to run the cell once you have typed in your code.
# </div>

# %% [markdown]
# # Optimization
#
#
# We saw from the results above that the total operating cost for the base case was $442,297 per year. We are producing 0.162 mol/s of benzene at a purity of 89.5%. However, we are losing around 43.3% of benzene in F101 vapor outlet stream.
#
# Let us try to minimize this cost such that:
# - we are producing at least 0.18 mol/s of benzene as distillate i.e. our product stream
# - purity of benzene i.e. the mole fraction of benzene in the distillate is at least 99%
# - restricting the benzene loss in F101 vapor outlet to less than 20%
#
# For this problem, our decision variables are as follows:
# - H101 outlet temperature
# - R101 outlet temperature
# - F101 outlet temperature
# - H102 outlet temperature
# - Condenser pressure
# - reflux ratio
# - boilup ratio

# %% [markdown]
# Let us declare our objective function for this problem.

# %%
m.fs.objective = Objective(expr=m.fs.operating_cost + m.fs.capital_cost)

# %% [markdown]
# Now, we need to unfix the decision variables as we had solved a square problem (degrees of freedom = 0) until now.

# %%
m.fs.H101.outlet.temperature.unfix()
m.fs.R101.conversion.unfix()
m.fs.F101.vap_outlet.temperature.unfix()
m.fs.D101.condenser.condenser_pressure.unfix()
m.fs.D101.condenser.reflux_ratio.unfix()
m.fs.D101.reboiler.boilup_ratio.unfix()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Let us now unfix the remaining variable: the temperature of the outlet from H102
#
# Use Shift+Enter to run the cell once you have typed in your code.
# </div>

# %%
# Todo: Unfix the temperature of the outlet from H102
m.fs.H102.outlet.temperature.unfix()

# %% [markdown]
# Next, we need to set bounds on these decision variables to values shown below:
#
#  - H101 outlet temperature [500, 600] K
#  - R101 outlet temperature [600, 900] K
#  - F101 outlet temperature [298, 450] K
#  - H102 outlet temperature [350, 400] K
#  - D101 condenser pressure [101325, 150000] Pa
#  - D101 reflux ratio [0.1, 5]
#  - D101 boilup ratio [0.1, 5]

# %%
# Set bounds on the temperature of the outlet from H101
m.fs.H101.outlet.temperature[0].setlb(500)
m.fs.H101.outlet.temperature[0].setub(600)

# Set bounds on the temperature of the outlet from R101
m.fs.R101.outlet.temperature[0].setlb(600)
m.fs.R101.outlet.temperature[0].setub(900)

# Set bounds on the volume of the reactor R101
m.fs.R101.volume[0].setlb(0)

# Set bounds on the temperature of the vapor outlet from F101
m.fs.F101.vap_outlet.temperature[0].setlb(298)
m.fs.F101.vap_outlet.temperature[0].setub(450.0)

# Set bounds on the temperature of the outlet from H102
m.fs.H102.outlet.temperature[0].setlb(350)
m.fs.H102.outlet.temperature[0].setub(400)

# Set bounds on the pressure inside the condenser
m.fs.D101.condenser.condenser_pressure.setlb(101325)
m.fs.D101.condenser.condenser_pressure.setub(150000)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Now, set the bounds for the D101 reflux ratio and boilup ratio.
#
# Use Shift+Enter to run the cell once you have typed in your code.
# </div>

# %%
# Todo: Set bounds on the reflux ratio
m.fs.D101.condenser.reflux_ratio.setlb(0.1)
m.fs.D101.condenser.reflux_ratio.setub(5)

# Todo: Set bounds on the boilup ratio
m.fs.D101.reboiler.boilup_ratio.setlb(0.1)
m.fs.D101.reboiler.boilup_ratio.setub(5)

# %% [markdown]
# Now, the only things left to define are our constraints on overhead loss in F101, distillate flowrate and its purity. Let us first look at defining a constraint for the overhead loss in F101 where we are restricting the benzene leaving the vapor stream to less than 20 % of the benzene available in the reactor outlet.

# %%
# Ensure that the overhead loss of benzene from F101 <= 20%
m.fs.overhead_loss = Constraint(
    expr=m.fs.F101.vap_outlet.flow_mol_phase_comp[0, "Vap", "benzene"]
    <= 0.20 * m.fs.R101.outlet.flow_mol_phase_comp[0, "Vap", "benzene"]
)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Inline Exercise:</b>
# Now, add the constraint such that we are producing at least 0.18 mol/s of benzene in the product stream which is the distillate of D101. Let us name this constraint as m.fs.product_flow.
#
# Use Shift+Enter to run the cell once you have typed in your code.
# </div>

# %%
# Todo: Add minimum product flow constraint
m.fs.product_flow = Constraint(expr=m.fs.D101.condenser.distillate.flow_mol[0] >= 0.18)

# %% [markdown]
# Let us add the final constraint on product purity or the mole fraction of benzene in the distillate such that it is at least greater than 99%.

# %%
m.fs.product_purity = Constraint(
    expr=m.fs.D101.condenser.distillate.mole_frac_comp[0, "benzene"] >= 0.99
)

# %% [markdown]
# We have now defined the optimization problem and we are now ready to solve this problem.

# %%
results = solver.solve(m, tee=True)
# Out:
# WARNING: model contains export suffix 'scaling_factor' that contains 3
# component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'scaling_factor' that contains 150 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# Ipopt 3.13.2: nlp_scaling_method=gradient-based
# tol=1e-06
# max_iter=200
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     4077
# Number of nonzeros in inequality constraint Jacobian.:        6
# Number of nonzeros in Lagrangian Hessian.............:     2398
#
# Total number of variables............................:     1176
#                      variables with only lower bounds:      113
#                 variables with lower and upper bounds:      372
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1169
# Total number of inequality constraints...............:        3
#         inequality constraints with only lower bounds:        2
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        1
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.4230044e+05 2.99e+05 9.90e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.3740502e+05 2.91e+05 1.40e+02  -1.0 3.15e+06    -  3.68e-01 2.47e-02f  1
#    2  4.3537346e+05 2.78e+05 1.70e+02  -1.0 1.79e+06    -  3.32e-01 4.72e-02h  1
#    3  4.2823406e+05 2.20e+05 4.55e+02  -1.0 2.96e+06    -  2.93e-02 1.35e-01h  1
#    4  4.2263320e+05 1.44e+05 1.41e+03  -1.0 7.00e+06    -  5.13e-01 2.04e-01h  1
#    5  4.2227715e+05 8.16e+04 1.73e+04  -1.0 6.06e+06    -  6.05e-01 4.28e-01h  1
#    6  4.2633050e+05 4.54e+04 1.10e+06  -1.0 4.33e+06    -  9.27e-01 5.07e-01h  1
#    7  4.3800268e+05 1.94e+04 6.01e+09  -1.0 2.41e+06    -  9.90e-01 9.45e-01h  1
#    8  4.3872375e+05 1.83e+04 5.61e+09  -1.0 3.99e+05    -  5.24e-01 6.15e-02h  1
#    9  4.4511078e+05 4.10e+04 4.23e+10  -1.0 2.53e+05    -  9.96e-01 9.90e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.4855469e+05 9.66e+03 9.65e+09  -1.0 1.09e+03  -4.0 1.56e-01 7.12e-01h  1
#   11  4.5045344e+05 1.63e+03 1.81e+09  -1.0 5.84e+02  -4.5 3.50e-01 1.00e+00h  1
#   12  4.4990317e+05 5.85e+00 1.94e+06  -1.0 7.14e+01  -5.0 1.00e+00 1.00e+00f  1
#   13  4.4901257e+05 7.96e-01 2.21e+05  -1.0 1.89e+02  -5.4 1.00e+00 8.64e-01f  1
#   14  4.4877632e+05 7.61e+00 1.62e+05  -1.0 2.70e+02  -5.9 1.00e+00 1.00e+00f  1
#   15  4.4875220e+05 1.31e+00 1.82e+03  -1.0 1.30e+02  -6.4 1.00e+00 1.00e+00f  1
#   16  4.4814818e+05 1.22e+01 1.47e+06  -2.5 5.57e+02  -6.9 1.00e+00 1.00e+00f  1
#   17  4.4775691e+05 5.17e+01 7.72e+05  -2.5 1.15e+03  -7.3 1.00e+00 4.76e-01f  1
#   18  4.4644685e+05 1.01e+03 6.03e+03  -2.5 4.43e+03  -7.8 1.00e+00 1.00e+00f  1
#   19  4.4394459e+05 7.17e+03 2.03e+03  -2.5 1.03e+04  -8.3 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  4.4195008e+05 1.67e+04 1.26e+04  -2.5 1.23e+04  -8.8 1.00e+00 1.00e+00h  1
#   21  4.4234931e+05 2.98e+03 5.12e+03  -2.5 2.99e+03  -9.2 1.00e+00 1.00e+00h  1
#   22  4.4177131e+05 9.77e+00 7.33e+01  -2.5 7.23e+03  -9.7 5.89e-01 1.00e+00h  1
#   23  4.4125257e+05 1.47e+01 1.89e+02  -2.5 4.95e+04 -10.2 9.06e-01 1.12e-01f  1
#   24  4.4130441e+05 4.74e+00 3.40e+02  -2.5 2.74e+04    -  2.37e-01 1.00e+00h  1
#   25  4.3863299e+05 1.66e+03 5.55e+05  -2.5 1.09e+07    -  3.74e-03 1.30e-01f  1
#   26  4.3901628e+05 1.30e+03 7.57e+05  -2.5 1.00e+06    -  1.00e+00 2.42e-01h  1
#   27  4.3889076e+05 3.90e+01 2.64e+05  -2.5 2.28e+05    -  1.00e+00 1.00e+00h  1
#   28  4.3887395e+05 1.72e-01 7.72e+03  -2.5 1.30e+04    -  1.00e+00 1.00e+00h  1
#   29  4.3887375e+05 1.76e-05 1.43e-01  -2.5 1.49e+02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  4.3883024e+05 1.19e+02 8.64e+05  -5.7 1.58e+04    -  9.90e-01 9.93e-01f  1
#   31  4.3883619e+05 7.75e-02 7.14e+00  -5.7 1.05e+01    -  1.00e+00 1.00e+00h  1
#   32  4.3883619e+05 3.73e-08 1.40e-06  -5.7 4.00e-03    -  1.00e+00 1.00e+00h  1
#   33  4.3883617e+05 5.47e-05 3.63e-01  -8.0 1.01e+01    -  1.00e+00 1.00e+00h  1
#   34  4.3883617e+05 3.73e-08 1.48e-07  -8.0 5.41e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 34
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3883617282610510e+02    4.3883617282610509e+05
# Dual infeasibility......:   1.4843789056669910e-07    1.4843789056669910e-04
# Constraint violation....:   2.9103830456733704e-11    3.7252902984619147e-08
# Complementarity.........:   9.0909112227562300e-09    9.0909112227562292e-06
# Overall NLP error.......:   9.0909112227562300e-09    1.4843789056669910e-04
#
#
# Number of objective function evaluations             = 35
# Number of objective gradient evaluations             = 35
# Number of equality constraint evaluations            = 35
# Number of inequality constraint evaluations          = 35
# Number of equality constraint Jacobian evaluations   = 35
# Number of inequality constraint Jacobian evaluations = 35
# Number of Lagrangian Hessian evaluations             = 34
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.272
# Total CPU secs in NLP function evaluations           =      0.043
#
# EXIT: Optimal Solution Found.

# %%
# Check solver solve status
from pyomo.environ import TerminationCondition

assert results.solver.termination_condition == TerminationCondition.optimal

# %% [markdown]
# ## Optimization Results
#
# Display the results and product specifications

# %%
print("total cost = $", value(m.fs.capital_cost) + value(m.fs.operating_cost))
print("operating cost = $", value(m.fs.operating_cost))
print("capital cost = $", value(m.fs.capital_cost))
print()
print(
    "Distillate flowrate = ",
    value(m.fs.D101.condenser.distillate.flow_mol[0]()),
    "mol/s",
)
print(
    "Benzene purity = ",
    100 * value(m.fs.D101.condenser.distillate.mole_frac_comp[0, "benzene"]),
    "%",
)
print("Residue flowrate = ", value(m.fs.D101.reboiler.bottoms.flow_mol[0]()), "mol/s")
print(
    "Toluene purity = ",
    100 * value(m.fs.D101.reboiler.bottoms.mole_frac_comp[0, "toluene"]),
    "%",
)
print()
print("Conversion = ", 100 * value(m.fs.R101.conversion), "%")
print()
print(
    "Overhead benzene loss in F101 = ",
    100
    * value(m.fs.F101.vap_outlet.flow_mol_phase_comp[0, "Vap", "benzene"])
    / value(m.fs.R101.outlet.flow_mol_phase_comp[0, "Vap", "benzene"]),
    "%",
)
# Out:
# total cost = $ 438836.1728261052
# operating cost = $ 408879.32655326056
# capital cost = $ 29956.846272844636
#
# Distillate flowrate =  0.17999999002640005 mol/s
# Benzene purity =  98.99999900049089 %
# Residue flowrate =  0.10851548865489237 mol/s
# Toluene purity =  15.673253697718655 %
#
# Conversion =  93.38819856138736 %
#
# Overhead benzene loss in F101 =  17.34062708743134 %

# %%
import pytest

print(value(m.fs.operating_cost))
print(value(m.fs.capital_cost))

assert value(m.fs.operating_cost) == pytest.approx(408883.531, abs=100)
assert value(m.fs.capital_cost) == pytest.approx(29956.367, abs=100)
# Out:
# 408879.32655326056
# 29956.846272844636

# %% [markdown]
# Display optimal values for the decision variables

# %%
print("Optimal Values")
print()

print("H101 outlet temperature = ", value(m.fs.H101.outlet.temperature[0]), "K")

print()
print("R101 outlet temperature = ", value(m.fs.R101.outlet.temperature[0]), "K")

print()
print("F101 outlet temperature = ", value(m.fs.F101.vap_outlet.temperature[0]), "K")

print()
print("H102 outlet temperature = ", value(m.fs.H102.outlet.temperature[0]), "K")
# Out:
# Optimal Values
#
# H101 outlet temperature =  568.9258098903113 K
#
# R101 outlet temperature =  790.3695696330948 K
#
# F101 outlet temperature =  298.0 K
#
# H102 outlet temperature =  368.7411437085544 K

# %% [markdown]
# ### Key Takeaways
#
# Observe that the optimization was able to reduce the yearly operating cost from \\$427,593 to \\$408,342 (~4.5%). However, the amortized capital cost more than doubled from \\$14,704 to \\$29,927 due to the need to increase the conversion in the reactor (from 75% to 93%) to meet the production and purity constraints.
#
# Further, observe that the product flow rate and product purity are at their minimum values (0.18 mol/s and 99%, respectively). This is expected as increasing recovery would require more energy and cost to purify the product.
#
#
# Finally, observe that the operating temperature of the flash (F101) is almost at its lower bound. This helps in minimizing the amount of benzene in the vapor stream leaving the flash.
